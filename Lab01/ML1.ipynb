# %% [markdown]
# # Machine Learning - I

# %%
a = [1, 2, 3]
[a, a]
# Out:
# [[1, 2, 3], [1, 2, 3]]

# %%
#Operators
"1"+"1"
# Out:
# '11'

# %%
type("!")
# Out:
# str

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
marks=[10,20,30,40,50]

# %%
for i in marks:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
for i in range(len(marks)):
    print(marks[i])
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
pass_mark = 40

# %%
for mark in marks:
    print(mark)  
    if mark<pass_mark:
        print("fail")
    else: 
        print("pass")
    print("------------------")
# Out:
# 10
# fail
# ------------------
# 20
# fail
# ------------------
# 30
# fail
# ------------------
# 40
# pass
# ------------------
# 50
# pass
# ------------------

# %%
def d(num1=0,num2=0):
    return (num1-num2)

# %%
d(num1=3,num2=2)
# Out:
# 1

# %%
d(20)
# Out:
# 20

# %%
num1   # scope of the variable is just inside the defination not outside
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-d05396c398c6> in <module>
# ----> 1 num1
#
# NameError: name 'num1' is not defined

# %% [markdown]
# Strctured Data - data arranged in the form of rows and columns  (We use Pandas)
# Unstructured Data - Images, Vedios, Audios etc

# %% [markdown]
# # Python for DS

# %%
# pandas numpy scipy sklearn matplotlib

# %%
import pandas as pd
import numpy as np

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
marks
# Out:
# [10, 20, 30, 40, 50]

# %%
marks_series = pd.Series(marks)
marks_series
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
marks_series.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
marks_series.values
# Out:
# array([10, 20, 30, 40, 50], dtype=int64)

# %%
marks_series[1:]
# Out:
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
marks_series[:3]
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
marks_series.value_counts()
# Out:
# 40    1
# 10    1
# 20    1
# 30    1
# 50    1
# dtype: int64

# %%
sample_df =pd.DataFrame([marks, marks]).T
sample_df
# Out:
#     0   1
# 0  10  10
# 1  20  20
# 2  30  30
# 3  40  40
# 4  50  50

# %%
sample_df.columns=['mark1','mark2']
sample_df
# Out:
#    mark1  mark2
# 0     10     10
# 1     20     20
# 2     30     30
# 3     40     40
# 4     50     50

# %%
df= pd.read_csv("C:/Users/rashm/2.  Extras_BDA/test.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df['MSZoning']
# Out:
# 0       RH
# 1       RL
# 2       RL
# 3       RL
# 4       RL
#         ..
# 1454    RM
# 1455    RM
# 1456    RL
# 1457    RL
# 1458    RL
# Name: MSZoning, Length: 1459, dtype: object

# %%
df['MSZoning'].value_counts()
# Out:
# RL         1114
# RM          242
# FV           74
# C (all)      15
# RH           10
# Name: MSZoning, dtype: int64

# %%
df.shape
# Out:
# (1459, 80)

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           4
# LotFrontage      227
# LotArea            0
#                 ...
# MiscVal            0
# MoSold             0
# YrSold             0
# SaleType           1
# SaleCondition      0
# Length: 80, dtype: int64

# %%
df.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df.fillna['LotFrontage']

# %%
df[df['LotFrontage']>30]
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1447  2908          20       RL         58.0    10172   Pave   NaN      IR1
# 1451  2912          20       RL         80.0    13384   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
df.corr()
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.004993     0.009930  0.051492    -0.064887
# MSSubClass     0.004993    1.000000    -0.450505 -0.359537     0.034690
# LotFrontage    0.009930   -0.450505     1.000000  0.644608     0.182870
# LotArea        0.051492   -0.359537     0.644608  1.000000     0.107989
# OverallQual   -0.064887    0.034690     0.182870  0.107989     1.000000
# OverallCond    0.009553   -0.071768    -0.092312 -0.103402    -0.095874
# YearBuilt     -0.058647    0.040848     0.122356  0.048314     0.621910
# YearRemodAdd  -0.079437    0.046319     0.092603  0.036907     0.591267
# MasVnrArea    -0.021424   -0.012186     0.251533  0.188691     0.453991
# BsmtFinSF1    -0.045966   -0.058775     0.204621  0.185470     0.322583
# BsmtFinSF2     0.015862   -0.079093     0.046824  0.054199    -0.028199
# BsmtUnfSF      0.001203   -0.111080     0.092031  0.071681     0.243070
# ...
