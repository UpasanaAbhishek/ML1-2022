# %%
num=[3,0,-7,15,-2,1,8]

# %%
num
# Out:
# [3, 0, -7, 15, -2, 1, 8]

# %%
for n in num:
    print(n)
    if(n>0):
        print("positive")
    elif(n==0):
        print("zero")
    else:
        print("negative")
    print("***********")
# Out:
# 3
# positive
# ***********
# 0
# zero
# ***********
# -7
# negative
# ***********
# 15
# positive
# ***********
# -2
# negative
# ***********
# 1
# positive
# ***********
# 8
# positive
# ***********

# %%
a=int(input("Enter the first number:"))
b=int(input("Enter the second number:"))
def add(a,b):
    x=(a+b)
    print("the sum of two numbers:",x)
add(a,b)

def subtract(a,b):
    y=(a-b)
    print("the difference of two numbers:",y)
subtract(a,b)

def multiply(a,b):
    z=(a*b)
    print("the product of two numbers:",z)
multiply(a,b)

def divide(a,b):
    s=(a/b)
    print("the quotient of two numbers:",s)
divide(a,b)
# Out:
# Enter the first number:12
# Enter the second number:23
# the sum of two numbers: 35
# the difference of two numbers: -11
# the product of two numbers: 276
# the quotient of two numbers: 0.5217391304347826

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\DELL\Downloads\covid19.csv")

# %%
df
# Out:
#       iso_code    casedate     location continent  new_cases  new_deaths  \
# 0          AFG  31-12-2019  Afghanistan      Asia          0           0
# 1          AFG  01-01-2020  Afghanistan      Asia          0           0
# 2          AFG  02-01-2020  Afghanistan      Asia          0           0
# 3          AFG  03-01-2020  Afghanistan      Asia          0           0
# 4          AFG  04-01-2020  Afghanistan      Asia          0           0
# ...        ...         ...          ...       ...        ...         ...
# 29208      ZWE  08-07-2020     Zimbabwe    Africa         53           0
# 29209      ZWE  09-07-2020     Zimbabwe    Africa         98           0
# 29210      ZWE  10-07-2020     Zimbabwe    Africa         41           3
# 29211      ZWE  11-07-2020     Zimbabwe    Africa         16           1
# 29212      ZWE  12-07-2020     Zimbabwe    Africa         40           5
#
#        population  pop_density  median_age  gdp_per_capita  hosp_beds  \
# ...

# %%
df.head()
# Out:
#   iso_code    casedate     location continent  new_cases  new_deaths  \
# 0      AFG  31-12-2019  Afghanistan      Asia          0           0
# 1      AFG  01-01-2020  Afghanistan      Asia          0           0
# 2      AFG  02-01-2020  Afghanistan      Asia          0           0
# 3      AFG  03-01-2020  Afghanistan      Asia          0           0
# 4      AFG  04-01-2020  Afghanistan      Asia          0           0
#
#    population  pop_density  median_age  gdp_per_capita  hosp_beds      region
# 0    38928341       54.422        18.6        1803.987        0.5  South Asia
# 1    38928341       54.422        18.6        1803.987        0.5  South Asia
# 2    38928341       54.422        18.6        1803.987        0.5  South Asia
# 3    38928341       54.422        18.6        1803.987        0.5  South Asia
# 4    38928341       54.422        18.6        1803.987        0.5  South Asia

# %%
df.tail()
# Out:
#       iso_code    casedate  location continent  new_cases  new_deaths  \
# 29208      ZWE  08-07-2020  Zimbabwe    Africa         53           0
# 29209      ZWE  09-07-2020  Zimbabwe    Africa         98           0
# 29210      ZWE  10-07-2020  Zimbabwe    Africa         41           3
# 29211      ZWE  11-07-2020  Zimbabwe    Africa         16           1
# 29212      ZWE  12-07-2020  Zimbabwe    Africa         40           5
#
#        population  pop_density  median_age  gdp_per_capita  hosp_beds  \
# 29208    14862927       42.729        19.6        1899.775        1.7
# 29209    14862927       42.729        19.6        1899.775        1.7
# 29210    14862927       42.729        19.6        1899.775        1.7
# 29211    14862927       42.729        19.6        1899.775        1.7
# 29212    14862927       42.729        19.6        1899.775        1.7
#
#                 region
# 29208  Southern Africa
# 29209  Southern Africa
# 29210  Southern Africa
# 29211  Southern Africa
# ...

# %%
df['pop_density'].value_counts()
# Out:
# 7915.731    195
# 214.243     195
# 24.718      195
# 8.823       195
# 375.564     195
#            ...
# 212.841      95
# 53.508       94
# 64.281       73
# 437.352      72
# 73.562       59
# Name: pop_density, Length: 198, dtype: int64

# %%
df.shape
# Out:
# (29213, 12)

# %%
df.isna().sum()
# Out:
# iso_code             0
# casedate             0
# location             0
# continent            0
# new_cases            0
# new_deaths           0
# population           0
# pop_density       1254
# median_age        2870
# gdp_per_capita    3184
# hosp_beds         5198
# region               0
# dtype: int64

# %%
df.describe()
# Out:
#           new_cases    new_deaths    population   pop_density    median_age  \
# count  29213.000000  29213.000000  2.921300e+04  27959.000000  26343.000000
# mean     435.914387     19.365283  4.637268e+07    370.987357     31.744881
# std     2572.856058    119.892993  1.664972e+08   1703.726597      9.045025
# min        0.000000      0.000000  8.090000e+02      0.137000     15.100000
# 25%        0.000000      0.000000  1.886202e+06     37.728000     24.400000
# 50%        4.000000      0.000000  8.655541e+06     93.105000     31.900000
# 75%       78.000000      2.000000  3.125544e+07    222.873000     40.100000
# max    66625.000000   4928.000000  1.439324e+09  19347.500000     48.200000
#
#        gdp_per_capita     hosp_beds
# count    26029.000000  24015.000000
# mean     21890.228387      3.167999
# std      20934.220990      2.575163
# min        661.240000      0.100000
# 25%       6171.884000      1.380000
# 50%      15183.616000      2.540000
# ...

# %%
df.mean()
# Out:
# new_cases         4.359144e+02
# new_deaths        1.936528e+01
# population        4.637268e+07
# pop_density       3.709874e+02
# median_age        3.174488e+01
# gdp_per_capita    2.189023e+04
# hosp_beds         3.167999e+00
# dtype: float64

# %%
df.fillna(df.mean())
# Out:
#       iso_code    casedate     location continent  new_cases  new_deaths  \
# 0          AFG  31-12-2019  Afghanistan      Asia          0           0
# 1          AFG  01-01-2020  Afghanistan      Asia          0           0
# 2          AFG  02-01-2020  Afghanistan      Asia          0           0
# 3          AFG  03-01-2020  Afghanistan      Asia          0           0
# 4          AFG  04-01-2020  Afghanistan      Asia          0           0
# ...        ...         ...          ...       ...        ...         ...
# 29208      ZWE  08-07-2020     Zimbabwe    Africa         53           0
# 29209      ZWE  09-07-2020     Zimbabwe    Africa         98           0
# 29210      ZWE  10-07-2020     Zimbabwe    Africa         41           3
# 29211      ZWE  11-07-2020     Zimbabwe    Africa         16           1
# 29212      ZWE  12-07-2020     Zimbabwe    Africa         40           5
#
#        population  pop_density  median_age  gdp_per_capita  hosp_beds  \
# ...

# %%
df.fillna(df.mean())[:20]
# Out:
#    iso_code    casedate     location continent  new_cases  new_deaths  \
# 0       AFG  31-12-2019  Afghanistan      Asia          0           0
# 1       AFG  01-01-2020  Afghanistan      Asia          0           0
# 2       AFG  02-01-2020  Afghanistan      Asia          0           0
# 3       AFG  03-01-2020  Afghanistan      Asia          0           0
# 4       AFG  04-01-2020  Afghanistan      Asia          0           0
# 5       AFG  05-01-2020  Afghanistan      Asia          0           0
# 6       AFG  06-01-2020  Afghanistan      Asia          0           0
# 7       AFG  07-01-2020  Afghanistan      Asia          0           0
# 8       AFG  08-01-2020  Afghanistan      Asia          0           0
# 9       AFG  09-01-2020  Afghanistan      Asia          0           0
# 10      AFG  10-01-2020  Afghanistan      Asia          0           0
# 11      AFG  11-01-2020  Afghanistan      Asia          0           0
# ...

# %%
df.corr()
# Out:
#                 new_cases  new_deaths  population  pop_density  median_age  \
# new_cases        1.000000    0.759405    0.211246    -0.022512    0.063314
# new_deaths       0.759405    1.000000    0.161650    -0.024387    0.100223
# population       0.211246    0.161650    1.000000    -0.024616    0.013858
# pop_density     -0.022512   -0.024387   -0.024616     1.000000    0.129496
# median_age       0.063314    0.100223    0.013858     0.129496    1.000000
# gdp_per_capita   0.072396    0.086095   -0.081892     0.298107    0.619316
# hosp_beds       -0.021662   -0.018898   -0.046432     0.327033    0.659926
#
#                 gdp_per_capita  hosp_beds
# new_cases             0.072396  -0.021662
# new_deaths            0.086095  -0.018898
# population           -0.081892  -0.046432
# pop_density           0.298107   0.327033
# median_age            0.619316   0.659926
# gdp_per_capita        1.000000   0.263702
# hosp_beds             0.263702   1.000000

# %%
df=pd.DataFrame(data=DataValues,columns=ColumnNames)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-9c9240dfa839> in <module>
# ----> 1 df=pd.DataFrame(data=DataValues,columns=ColumnNames)
#       2 print(df.head())
#
# NameError: name 'DataValues' is not defined

# %%
CrosstabResult=pd.crosstab(index=df['iso_code'],columns=df['continent'])
print(CrosstabResult)
# Out:
# continent  Africa  Asia  Europe  North America  Oceania  South America
# iso_code
# ABW             0     0       0            112        0              0
# AFG             0   185       0              0        0              0
# AGO           113     0       0              0        0              0
# AIA             0     0       0            108        0              0
# ALB             0     0     126              0        0              0
# ...           ...   ...     ...            ...      ...            ...
# XKX             0     0     121              0        0              0
# YEM             0    94       0              0        0              0
# ZAF           127     0       0              0        0              0
# ZMB           116     0       0              0        0              0
# ZWE           114     0       0              0        0              0
#
# [209 rows x 6 columns]

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'new_cases'}>,
#         <AxesSubplot:title={'center':'new_deaths'}>,
#         <AxesSubplot:title={'center':'population'}>],
#        [<AxesSubplot:title={'center':'pop_density'}>,
#         <AxesSubplot:title={'center':'median_age'}>,
#         <AxesSubplot:title={'center':'gdp_per_capita'}>],
#        [<AxesSubplot:title={'center':'hosp_beds'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.hist(column='population')
# Out:
# array([[<AxesSubplot:title={'center':'population'}>]], dtype=object)

# %%
df.plot.hist();

# %%
codes=pd.Series(['AFG','DZA','AND','ATG','BLR','KHM'])
region=pd.Series(['south asia','north africa','caribbean','south america','west africa','western europe'])
pd.DataFrame({"codes": codes, "region": region})
# Out:
#   codes          region
# 0   AFG      south asia
# 1   DZA    north africa
# 2   AND       caribbean
# 3   ATG   south america
# 4   BLR     west africa
# 5   KHM  western europe

# %%
df.iloc[0:3, 1:4]
# Out:
#      casedate     location continent
# 0  31-12-2019  Afghanistan      Asia
# 1  01-01-2020  Afghanistan      Asia
# 2  02-01-2020  Afghanistan      Asia

# %%
df.iloc[::-1]
# Out:
#       iso_code    casedate     location continent  new_cases  new_deaths  \
# 29212      ZWE  12-07-2020     Zimbabwe    Africa         40           5
# 29211      ZWE  11-07-2020     Zimbabwe    Africa         16           1
# 29210      ZWE  10-07-2020     Zimbabwe    Africa         41           3
# 29209      ZWE  09-07-2020     Zimbabwe    Africa         98           0
# 29208      ZWE  08-07-2020     Zimbabwe    Africa         53           0
# ...        ...         ...          ...       ...        ...         ...
# 4          AFG  04-01-2020  Afghanistan      Asia          0           0
# 3          AFG  03-01-2020  Afghanistan      Asia          0           0
# 2          AFG  02-01-2020  Afghanistan      Asia          0           0
# 1          AFG  01-01-2020  Afghanistan      Asia          0           0
# 0          AFG  31-12-2019  Afghanistan      Asia          0           0
#
#        population  pop_density  median_age  gdp_per_capita  hosp_beds  \
# ...

# %%
df.iloc[24:50]
# Out:
#    iso_code    casedate     location continent  new_cases  new_deaths  \
# 24      AFG  24-01-2020  Afghanistan      Asia          0           0
# 25      AFG  25-01-2020  Afghanistan      Asia          0           0
# 26      AFG  26-01-2020  Afghanistan      Asia          0           0
# 27      AFG  27-01-2020  Afghanistan      Asia          0           0
# 28      AFG  28-01-2020  Afghanistan      Asia          0           0
# 29      AFG  29-01-2020  Afghanistan      Asia          0           0
# 30      AFG  30-01-2020  Afghanistan      Asia          0           0
# 31      AFG  31-01-2020  Afghanistan      Asia          0           0
# 32      AFG  01-02-2020  Afghanistan      Asia          0           0
# 33      AFG  02-02-2020  Afghanistan      Asia          0           0
# 34      AFG  03-02-2020  Afghanistan      Asia          0           0
# 35      AFG  04-02-2020  Afghanistan      Asia          0           0
# ...

# %%
df.iloc[2, 6]
# Out:
# 38928341
