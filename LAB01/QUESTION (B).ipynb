# %% [markdown]
# # (B)

# %% [markdown]
# # 1.Write a program that uses an if-else ladder.

# %%
#Program to find whether the given number is odd or even.

num = int(input("Enter a number: "))

if num % 2 == 0:
  print("The number is EVEN")
else:
  print("The number is ODD")
# Out:
# Enter a number: 4
# The number is EVEN

# %% [markdown]
# # 2.Write 5 different functions and call them in one program.

# %%
#Program code of Simple Calculator

a=int(input("Enter the first number: "))
b=int(input("Enter the second number: "))
op=input("Enter the operation- +,-,*,/ or %: ")
def add(a,b):
    return a+b
def subtract(a,b):
    return a-b
def multiply(a,b):
    return a*b
def divide(a,b):
    return a//b
def modulus(a,b):
    return a%b
if op=='+':
    addition = add(a,b)
    print ("The sum is: ",addition)
elif op=="-":
        difference=subtract(a,b)
        print("The difference is: ",difference)
elif op=='*':
          product=multiply(a,b)
          print("The product is: ",product)
elif op=='/':
         Quotient=divide(a,b)
         print("The quotient is: ",Quotient)
elif op=='%':
        remainder=modulus(a,b)
        print("The remainder is: ",remainder)
else:
      print("Oops!!Not possible")
# Out:
# Enter the first number: 12
# Enter the second number: 12
# Enter the operation- +,-,*,/ or %: +
# The sum is:  24

# %% [markdown]
# # 3.Read any dataset from perform a missing value treatment, check for distribution of each variable, find the correlation matrix and write conclusions from the matrix.

# %%
dff=pd.read_csv("CarPrice_Assignment.csv")

# %%
dff
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
dff.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
dff.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
dff.describe().T
# Out:
#                   count          mean          std      min      25%  \
# car_ID            205.0    103.000000    59.322565     1.00    52.00
# symboling         205.0      0.834146     1.245307    -2.00     0.00
# wheelbase         205.0     98.756585     6.021776    86.60    94.50
# carlength         205.0    174.049268    12.337289   141.10   166.30
# carwidth          205.0     65.907805     2.145204    60.30    64.10
# carheight         205.0     53.724878     2.443522    47.80    52.00
# curbweight        205.0   2555.565854   520.680204  1488.00  2145.00
# enginesize        205.0    126.907317    41.642693    61.00    97.00
# boreratio         205.0      3.329756     0.270844     2.54     3.15
# stroke            205.0      3.255415     0.313597     2.07     3.11
# compressionratio  205.0     10.142537     3.972040     7.00     8.60
# horsepower        205.0    104.117073    39.544167    48.00    70.00
# peakrpm           205.0   5125.121951   476.985643  4150.00  4800.00
# ...

# %%
dff=dff.drop(['car_ID'],axis=1)

# %%
dff
# Out:
#      symboling                   CarName fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
dff['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
#HANDLING DUPLICATE VALUES IN CAR NAMES
#nissan and Nissan are same
#toyota and toyouta are same
#vokswagen , volkswagen and vw are same
#mazda and maxda are same
#porcshce and porsche are same

# %%
dff['CarName'] = dff['CarName'].replace({'maxda': 'mazda', 'nissan': 'Nissan', 'porcshce': 'porsche', 'toyouta': 'toyota', 
                            'vokswagen': 'volkswagen', 'vw': 'volkswagen'})

# %%
dff['CarName'].unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
# Segregation of Numerical and Categorical Variables/Columns
cat_col = dff.select_dtypes(include=['object']).columns
num_col = dff.select_dtypes(exclude=['object']).columns

# %%
cat_col
# Out:
# Index(['CarName', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'enginetype', 'cylindernumber',
#        'fuelsystem'],
#       dtype='object')

# %%
num_col
# Out:
# Index(['symboling', 'wheelbase', 'carlength', 'carwidth', 'carheight',
#        'curbweight', 'enginesize', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
#Visualizing the distribution of car prices
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8,8))

plt.title('Car Price Distribution Plot')
sns.distplot(dff['price'])
# Out:
# C:\Users\USER1\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:title={'center':'Car Price Distribution Plot'}, xlabel='price', ylabel='Density'>

# %%
df_v=pd.DataFrame(dff['enginetype'].value_counts())
plot = df_v.plot.pie(y='enginetype', figsize=(8, 8));

# %%
dff[num_col].corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
sns.heatmap(dff[num_col].corr(),annot = True);

# %% [markdown]
# wheelbase has a high positive correlation with carlength,carwidth and curbweight
# carlength has a high positive correlation with curbweight
# carlength has a negative correlation with highwaympg
# carwidth has a high positive correlation with curbweight and engine size
# enginesize has a high positive correlation with horsepower
# curbweight has a high positive correlation with engine size and horse power, negative correlation with highwaympg
# horsepower has a negative correlation with citympg and highwaympg
# citympg and highwaympg are highly correlated
# Price Prediction with PyCaret

# %% [markdown]
# # 4.Read a dataset and perform slice it in different ways

# %%
import pandas as pd

# %%
df=pd.read_csv("Toy Sales Data.csv")

# %%
df.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units  \
# 0        1  2017-01-01        24           4      1
# 1        2  2017-01-01        28           1      1
# 2        3  2017-01-01         6           8      1
# 3        4  2017-01-01        48           7      1
# 4        5  2017-01-01        44          18      1
#
#                     Store_Name      Store_City Store_Location Store_Open_Date  \
# 0  Maven Toys Aguascalientes 1  Aguascalientes       Downtown      2010-07-31
# 1          Maven Toys Puebla 2          Puebla       Downtown      2011-04-01
# 2        Maven Toys Mexicali 1        Mexicali     Commercial      2003-12-13
# 3        Maven Toys Saltillo 2        Saltillo     Commercial      2016-03-23
# 4          Maven Toys Puebla 3          Puebla    Residential      2014-12-27
#
#        Product_Name   Product_Category Product_Cost Product_Price  \
# 0  Chutes & Ladders              Games       $9.99        $12.99
# ...

# %%
df[1:5]
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units             Store_Name  \
# 1        2  2017-01-01        28           1      1    Maven Toys Puebla 2
# 2        3  2017-01-01         6           8      1  Maven Toys Mexicali 1
# 3        4  2017-01-01        48           7      1  Maven Toys Saltillo 2
# 4        5  2017-01-01        44          18      1    Maven Toys Puebla 3
#
#   Store_City Store_Location Store_Open_Date   Product_Name   Product_Category  \
# 1     Puebla       Downtown      2011-04-01  Action Figure               Toys
# 2   Mexicali     Commercial      2003-12-13  Deck Of Cards              Games
# 3   Saltillo     Commercial      2016-03-23       Dart Gun  Sports & Outdoors
# 4     Puebla    Residential      2014-12-27    Lego Bricks               Toys
#
#   Product_Cost Product_Price  Stock_On_Hand
# 1       $9.99        $15.99             6.0
# 2       $3.99         $6.99            50.0
# 3      $11.99        $15.99            28.0
# ...

# %%
df.iloc[3:10]
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units                Store_Name  \
# 3        4  2017-01-01        48           7      1     Maven Toys Saltillo 2
# 4        5  2017-01-01        44          18      1       Maven Toys Puebla 3
# 5        6  2017-01-01         1          31      1  Maven Toys Guadalajara 1
# 6        7  2017-01-01        40           7      1       Maven Toys Toluca 2
# 7        8  2017-01-01        19           2      1       Maven Toys Puebla 1
# 8        9  2017-01-01        38          21      1    Maven Toys Chihuahua 2
# 9       10  2017-01-01        21           8      1     Maven Toys Santiago 1
#
#     Store_City Store_Location Store_Open_Date        Product_Name  \
# 3     Saltillo     Commercial      2016-03-23            Dart Gun
# 4       Puebla    Residential      2014-12-27         Lego Bricks
# 5  Guadalajara    Residential      1992-09-18        Splash Balls
# 6       Toluca     Commercial      2014-05-27            Dart Gun
# ...

# %%
df[-20::]
# Out:
#         Sale_ID        Date  Store_ID  Product_ID  Units  \
# 829242   829243  2018-09-30        48          15      1
# 829243   829244  2018-09-30        48          35      1
# 829244   829245  2018-09-30        15          19      1
# 829245   829246  2018-09-30        17          30      1
# 829246   829247  2018-09-30        30          18      2
# 829247   829248  2018-09-30        44          25      1
# 829248   829249  2018-09-30         9           2      1
# 829249   829250  2018-09-30        13           2      2
# 829250   829251  2018-09-30         7           7      1
# 829251   829252  2018-09-30         9          18      1
# 829252   829253  2018-09-30        24          19      1
# 829253   829254  2018-09-30        45          25      1
# 829254   829255  2018-09-30        23           3      3
# 829255   829256  2018-09-30        25          19      1
# 829256   829257  2018-09-30        47          25      1
# ...

# %%
df.loc[:,"Store_City"]
# Out:
# 0          Aguascalientes
# 1                  Puebla
# 2                Mexicali
# 3                Saltillo
# 4                  Puebla
#                ...
# 829257     Aguascalientes
# 829258    San Luis Potosi
# 829259         Guanajuato
# 829260           Mexicali
# 829261         Hermosillo
# Name: Store_City, Length: 829262, dtype: object

# %%
df.iloc[[9,2],[4,9]]
# Out:
#    Units   Product_Name
# 9      1  Deck Of Cards
# 2      1  Deck Of Cards

# %% [markdown]
# # 5.Can we find correlation between two categorical variables? How?

# %% [markdown]
# Yes. We can have correlation between 2 categorical variables. Spearman Rank Correlation is a method to do it
