# %% [markdown]
# # **Lab 02**

# %% [markdown]
# ## **21BDA17**

# %% [markdown]
# ## **Alen Roy**

# %% [markdown]
# **PART A**

# %% [markdown]
# 1.Perform EDA and upload the notebook.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
df=pd.read_csv("Fish.csv")

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
df.sample(7)
# Out:
#    Species  Weight  Length1  Length2  Length3   Height   Width
# 96   Perch   225.0     22.0     24.0     25.5   7.2930  3.7230
# 1    Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 7    Bream   390.0     27.6     30.0     35.0  12.6700  4.6900
# 71  Parkki   300.0     24.0     26.0     29.0  11.3680  4.2340
# 36   Roach    69.0     16.5     18.2     20.3   5.2983  2.8217
# 73   Perch    32.0     12.5     13.7     14.7   3.5280  1.9992
# 91   Perch   130.0     20.5     22.5     24.0   5.8560  3.6240

# %%
df['Species'].value_counts()
# Out:
# Perch        56
# Bream        35
# Roach        20
# Pike         17
# Smelt        14
# Parkki       11
# Whitefish     6
# Name: Species, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Species  159 non-null    object
#  1   Weight   159 non-null    float64
#  2   Length1  159 non-null    float64
#  3   Length2  159 non-null    float64
#  4   Length3  159 non-null    float64
#  5   Height   159 non-null    float64
#  6   Width    159 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 8.8+ KB

# %%
df.dtypes
# Out:
# Species     object
# Weight     float64
# Length1    float64
# Length2    float64
# Length3    float64
# Height     float64
# Width      float64
# dtype: object

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
df.isnull().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
df.Species.unique()
# Out:
# array(['Bream', 'Roach', 'Whitefish', 'Parkki', 'Perch', 'Pike', 'Smelt'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
df.corr()
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %% [markdown]
# **HISTOGRAM**

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Weight'}>,
#         <AxesSubplot:title={'center':'Length1'}>],
#        [<AxesSubplot:title={'center':'Length2'}>,
#         <AxesSubplot:title={'center':'Length3'}>],
#        [<AxesSubplot:title={'center':'Height'}>,
#         <AxesSubplot:title={'center':'Width'}>]], dtype=object)

# %% [markdown]
# **REL PLOT**

# %%
sns.relplot(x = "Height", y = "Width", data = df)

# %% [markdown]
# **SCATTER PLOT**

# %%
sns.scatterplot(x = "Height", y = "Width", hue= "Species", data = df);

# %%
sns.scatterplot(x = "Height", y = "Weight", hue= "Species", style= "Species", data = df);

# %%
sns.relplot(x = "Height", y = "Weight", hue = "Species", height = 7, data = df, alpha = 0.7)

# %%
df.groupby('Species')['Height'].mean()
# Out:
# Species
# Bream        15.183211
# Parkki        8.962427
# Perch         7.861870
# Pike          7.713771
# Roach         6.694795
# Smelt         2.209371
# Whitefish    10.027167
# Name: Height, dtype: float64

# %% [markdown]
# **CAT PLOT**

# %%
sns.catplot(x = "Species", y = "Height", data = df);

# %% [markdown]
# **SWARM PLOT**

# %%
sns.swarmplot(x = "Species", y = "Height", data =df);

# %%
df.groupby(['Length1', 'Length2','Length3'])['Species'].count()
# Out:
# Length1  Length2  Length3
# 7.5      8.4      8.8        1
# 9.3      9.8      10.8       1
# 10.0     10.5     11.6       1
# 10.1     10.6     11.6       1
# 10.4     11.0     12.0       1
#                             ..
# 44.8     48.0     51.2       1
# 48.3     51.7     55.1       1
# 52.0     56.0     59.7       1
# 56.0     60.0     64.0       2
# 59.0     63.4     68.0       1
# Name: Species, Length: 143, dtype: int64

# %%
sns.swarmplot(x ="Species", y = "Height", data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Height'>

# %%
sns.swarmplot(x ="Species", y = "Height", hue = "Species", alpha =.7, data = df);

# %% [markdown]
# **BOX PLOT**

# %%
sns.boxplot(x ="Species", y = "Weight", data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Weight'>

# %%
sns.boxplot(x = "Species", y = "Height", hue = "Species", data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Height'>

# %% [markdown]
# **BOXEN PLOT**

# %%
sns.boxenplot(x= "Species", y = "Height", hue = "Species", data =df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Height'>

# %% [markdown]
# **VIOLIN PLOT**

# %%
sns.violinplot(x ="Species", y = "Height", hue = "Species", data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Height'>

# %% [markdown]
# **BAR PLOT**

# %%
sns.barplot(x = "Species", y= "Weight", hue = "Species", data = df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Weight'>

# %% [markdown]
# **POINT PLOT**

# %%
sns.pointplot(x = "Height", y = "Species", data= df)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Species'>

# %% [markdown]
# **EXTRA 5 PLOTS**

# %% [markdown]
# **1.JOINT PLOT**

# %%
sns.jointplot(x="Height", y="Weight", data=df);

# %% [markdown]
# **2.PAIR PLOT**

# %%
sns.pairplot(data=df, hue="Species");

# %% [markdown]
# **3.LM PLOT**

# %%
sns.lmplot(x="Height", y="Weight", data=df)

# %% [markdown]
# **4.DISPLOT**

# %%
sns.displot(data= df,x="Height")

# %% [markdown]
# **5.LINE PLOT**

# %%
sns.lineplot(x="Height", y="Weight", data=df)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>
