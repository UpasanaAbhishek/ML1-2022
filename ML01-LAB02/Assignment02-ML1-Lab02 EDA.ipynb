# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set(style = "darkgrid")
sns.set(rc = {'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv("Real estate.csv", index_col=0)

# %%
df
# Out:
#      X1 transaction date  X2 house age  \
# No
# 1               2012.917          32.0
# 2               2012.917          19.5
# 3               2013.583          13.3
# 4               2013.500          13.3
# 5               2012.833           5.0
# ..                   ...           ...
# 410             2013.000          13.7
# 411             2012.667           5.6
# 412             2013.250          18.8
# 413             2013.000           8.1
# 414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 1                                  84.87882                               10
# 2                                 306.59470                                9
# 3                                 561.98450                                5
# 4                                 561.98450                                5
# 5                                 390.56840                                5
# ...

# %%
df.head()
# Out:
#     X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# No
# 1              2012.917          32.0                                84.87882
# 2              2012.917          19.5                               306.59470
# 3              2013.583          13.3                               561.98450
# 4              2013.500          13.3                               561.98450
# 5              2012.833           5.0                               390.56840
#
#     X4 number of convenience stores  X5 latitude  X6 longitude  \
# No
# 1                                10     24.98298     121.54024
# 2                                 9     24.98034     121.53951
# 3                                 5     24.98746     121.54391
# 4                                 5     24.98746     121.54391
# 5                                 5     24.97937     121.54245
#
#     Y house price of unit area
# No
# 1                         37.9
# 2                         42.2
# ...

# %%
df.sample(5)
# Out:
#      X1 transaction date  X2 house age  \
# No
# 185             2012.750          14.1
# 324             2013.417          28.6
# 213             2013.333          17.6
# 215             2013.583          18.1
# 166             2012.917          13.7
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# No
# 185                               2615.4650                                0
# 324                                197.1338                                6
# 213                               1805.6650                                2
# 215                               1783.1800                                3
# 166                               1236.5640                                1
#
#      X5 latitude  X6 longitude  Y house price of unit area
# No
# 185     24.95495     121.56174                        21.8
# 324     24.97631     121.54436                        42.5
# 213     24.98672     121.52091                        31.1
# ...

# %%
df.columns
# Out:
# Index(['X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %% [markdown]
# **change column names**

# %%
df.columns = ['transaction date','house age','distance to the nearest MRT station','number of convenience stores','latitude','longitude','house price of unit area']

# %%
df.sample(5)
# Out:
#      transaction date  house age  distance to the nearest MRT station  \
# No
# 172          2013.083        3.6                             383.8624
# 349          2012.833        4.6                             259.6607
# 347          2013.417       13.2                            1712.6320
# 56           2012.833       31.7                            1160.6320
# 37           2012.917       14.7                            1935.0090
#
#      number of convenience stores  latitude  longitude  \
# No
# 172                             5  24.98085  121.54391
# 349                             6  24.97585  121.54516
# 347                             2  24.96412  121.51670
# 56                              0  24.94968  121.53009
# 37                              2  24.96386  121.51458
#
#      house price of unit area
# No
# 172                      58.8
# 349                      53.7
# 347                      30.8
# 56                       13.7
# 37                       22.9

# %%
df.head()
# Out:
#     transaction date  house age  distance to the nearest MRT station  \
# No
# 1           2012.917       32.0                             84.87882
# 2           2012.917       19.5                            306.59470
# 3           2013.583       13.3                            561.98450
# 4           2013.500       13.3                            561.98450
# 5           2012.833        5.0                            390.56840
#
#     number of convenience stores  latitude  longitude  \
# No
# 1                             10  24.98298  121.54024
# 2                              9  24.98034  121.53951
# 3                              5  24.98746  121.54391
# 4                              5  24.98746  121.54391
# 5                              5  24.97937  121.54245
#
#     house price of unit area
# No
# 1                       37.9
# 2                       42.2
# 3                       47.3
# 4                       54.8
# 5                       43.1

# %%
df.describe()
# Out:
#        transaction date   house age  distance to the nearest MRT station  \
# count        414.000000  414.000000                           414.000000
# mean        2013.148971   17.712560                          1083.885689
# std            0.281967   11.392485                          1262.109595
# min         2012.667000    0.000000                            23.382840
# 25%         2012.917000    9.025000                           289.324800
# 50%         2013.167000   16.100000                           492.231300
# 75%         2013.417000   28.150000                          1454.279000
# max         2013.583000   43.800000                          6488.021000
#
#        number of convenience stores    latitude   longitude  \
# count                    414.000000  414.000000  414.000000
# mean                       4.094203   24.969030  121.533361
# std                        2.945562    0.012410    0.015347
# min                        0.000000   24.932070  121.473530
# ...

# %% [markdown]
# **check for null values**

# %%
df.isnull().sum()
# Out:
# transaction date                       0
# house age                              0
# distance to the nearest MRT station    0
# number of convenience stores           0
# latitude                               0
# longitude                              0
# house price of unit area               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 1 to 414
# Data columns (total 7 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   transaction date                     414 non-null    float64
#  1   house age                            414 non-null    float64
#  2   distance to the nearest MRT station  414 non-null    float64
#  3   number of convenience stores         414 non-null    int64
#  4   latitude                             414 non-null    float64
#  5   longitude                            414 non-null    float64
#  6   house price of unit area             414 non-null    float64
# dtypes: float64(6), int64(1)
# memory usage: 25.9 KB

# %%
df.corr()
# Out:
#                                      transaction date  house age  \
# transaction date                             1.000000   0.017549
# house age                                    0.017549   1.000000
# distance to the nearest MRT station          0.060880   0.025622
# number of convenience stores                 0.009635   0.049593
# latitude                                     0.035058   0.054420
# longitude                                   -0.041082  -0.048520
# house price of unit area                     0.087491  -0.210567
#
#                                      distance to the nearest MRT station  \
# transaction date                                                0.060880
# house age                                                       0.025622
# distance to the nearest MRT station                             1.000000
# number of convenience stores                                   -0.602519
# latitude                                                       -0.591067
# ...

# %% [markdown]
# **visualization**

# %%
df.hist()
plt.show()

# %% [markdown]
# **relational plot**

# %%
sns.relplot(x = "house age", y = "house price of unit area", data = df, hue = "number of convenience stores")

# %% [markdown]
# **scatterplot**

# %%
sns.scatterplot(x = "house age", y = "house price of unit area", data = df, hue = "number of convenience stores")
# Out:
# <AxesSubplot:xlabel='house age', ylabel='house price of unit area'>

# %% [markdown]
# **pairplot**

# %%
sns.pairplot(df)

# %% [markdown]
# **heatmap plot**

# %%
sns.heatmap(df.corr(), annot=True, cmap = "inferno")
# Out:
# <AxesSubplot:>

# %% [markdown]
# **distribution plot**

# %%
sns.displot(data= df, x='house price of unit area')

# %% [markdown]
# **violin plot**

# %%
sns.violinplot(x = "transaction date", y = "house price of unit area", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='house price of unit area'>

# %% [markdown]
# **categorical plot**

# %%
sns.catplot(x = "transaction date", y = "house price of unit area", data = df)

# %% [markdown]
# **swarm plot**

# %%
sns.swarmplot(x = "transaction date", y = "house price of unit area", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='house price of unit area'>

# %% [markdown]
# **cluster map**

# %%
sns.clustermap(df.corr(), center=0)

# %% [markdown]
# **lm plot**

# %%
sns.lmplot(x = "house age", y = "house price of unit area", data = df)

# %%
sns.jointplot(x = "house age", y = "house price of unit area", data = df, kind="kde")

# %% [markdown]
# **box plot**

# %%
sns.boxplot(x = "transaction date", y = "house price of unit area", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='house price of unit area'>

# %% [markdown]
# **boxen plot**

# %%
sns.boxenplot(x = "transaction date", y = "house price of unit area", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='house price of unit area'>

# %% [markdown]
# **bar plot**

# %%
sns.barplot(x = "transaction date", y = "house price of unit area", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='house price of unit area'>

# %% [markdown]
# **count plot**

# %%
sns.countplot(x = "transaction date",hue = "number of convenience stores", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='count'>

# %% [markdown]
# **point plot**

# %%
sns.pointplot(x = "transaction date", y = "house price of unit area", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='house price of unit area'>

# %%
sns.regplot(x = "transaction date", y = "house price of unit area", data = df)
# Out:
# <AxesSubplot:xlabel='transaction date', ylabel='house price of unit area'>
