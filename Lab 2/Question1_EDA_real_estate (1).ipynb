# %% [markdown]
# (A) 1

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

# %%
import pandas as pd

# %%
real_estate = pd.read_csv("C:\\Users\\Soham\\Dropbox\\My PC (LAPTOP-AGG4JAFB)\\Downloads\\Real estate.csv")

# %%
real_estate.head()
# Out:
#    No  transaction date  house age  distance to the nearest MRT station  \
# 0   1          2012.917       32.0                             84.87882
# 1   2          2012.917       19.5                            306.59470
# 2   3          2013.583       13.3                            561.98450
# 3   4          2013.500       13.3                            561.98450
# 4   5          2012.833        5.0                            390.56840
#
#    number of convenience stores  latitude  longitude  house price of unit area
# 0                            10  24.98298  121.54024                      37.9
# 1                             9  24.98034  121.53951                      42.2
# 2                             5  24.98746  121.54391                      47.3
# 3                             5  24.98746  121.54391                      54.8
# 4                             5  24.97937  121.54245                      43.1

# %%
real_estate.columns
# Out:
# Index(['No', 'transaction date', 'house age',
#        'distance to the nearest MRT station', 'number of convenience stores',
#        'latitude', 'longitude', 'house price of unit area'],
#       dtype='object')

# %%
real_estate.columns = ['No','transaction date','house age','distance to the nearest MRT station','number of convenience stores','latitude','longitude','house price of unit area']
real_estate
# Out:
#       No  transaction date  house age  distance to the nearest MRT station  \
# 0      1          2012.917       32.0                             84.87882
# 1      2          2012.917       19.5                            306.59470
# 2      3          2013.583       13.3                            561.98450
# 3      4          2013.500       13.3                            561.98450
# 4      5          2012.833        5.0                            390.56840
# ..   ...               ...        ...                                  ...
# 409  410          2013.000       13.7                           4082.01500
# 410  411          2012.667        5.6                             90.45606
# 411  412          2013.250       18.8                            390.96960
# 412  413          2013.000        8.1                            104.81010
# 413  414          2013.500        6.5                             90.45606
#
#      number of convenience stores  latitude  longitude  \
# ...

# %%
real_estate["transaction date"] = real_estate["transaction date"].astype(int)

# %%
real_estate.isnull().sum()
# Out:
# No                                     0
# transaction date                       0
# house age                              0
# distance to the nearest MRT station    0
# number of convenience stores           0
# latitude                               0
# longitude                              0
# house price of unit area               0
# dtype: int64

# %%
real_estate['transaction date'].value_counts()
# Out:
# 2013    288
# 2012    126
# Name: transaction date, dtype: int64

# %%
real_estate['house age'].value_counts()
# Out:
# 0.0     17
# 13.6     7
# 16.2     6
# 13.2     6
# 16.4     6
#         ..
# 41.4     1
# 20.9     1
# 26.9     1
# 35.8     1
# 17.8     1
# Name: house age, Length: 236, dtype: int64

# %%
real_estate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   No                                   414 non-null    int64
#  1   transaction date                     414 non-null    int32
#  2   house age                            414 non-null    float64
#  3   distance to the nearest MRT station  414 non-null    float64
#  4   number of convenience stores         414 non-null    int64
#  5   latitude                             414 non-null    float64
#  6   longitude                            414 non-null    float64
#  7   house price of unit area             414 non-null    float64
# dtypes: float64(5), int32(1), int64(2)
# memory usage: 24.4 KB

# %%
real_estate.describe()
# Out:
#                No  transaction date   house age  \
# count  414.000000        414.000000  414.000000
# mean   207.500000       2012.695652   17.712560
# std    119.655756          0.460687   11.392485
# min      1.000000       2012.000000    0.000000
# 25%    104.250000       2012.000000    9.025000
# 50%    207.500000       2013.000000   16.100000
# 75%    310.750000       2013.000000   28.150000
# max    414.000000       2013.000000   43.800000
#
#        distance to the nearest MRT station  number of convenience stores  \
# count                           414.000000                    414.000000
# mean                           1083.885689                      4.094203
# std                            1262.109595                      2.945562
# min                              23.382840                      0.000000
# 25%                             289.324800                      1.000000
# 50%                             492.231300                      4.000000
# ...

# %%
real_estate.isna().sum()
# Out:
# No                                     0
# transaction date                       0
# house age                              0
# distance to the nearest MRT station    0
# number of convenience stores           0
# latitude                               0
# longitude                              0
# house price of unit area               0
# dtype: int64

# %%
real_estate.corr()
# Out:
#                                            No  transaction date  house age  \
# No                                   1.000000          0.007379  -0.032808
# transaction date                     0.007379          1.000000   0.049171
# house age                           -0.032808          0.049171   1.000000
# distance to the nearest MRT station -0.013573          0.016519   0.025622
# number of convenience stores        -0.012699         -0.005586   0.049593
# latitude                            -0.010110          0.008118   0.054420
# longitude                           -0.011059          0.013177  -0.048520
# house price of unit area            -0.028587          0.081545  -0.210567
#
#                                      distance to the nearest MRT station  \
# No                                                             -0.013573
# transaction date                                                0.016519
# ...

# %%
sns.relplot(x = "transaction date", y = "house age", data = real_estate, dtype=float64)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-342897d49508> in <module>
# ----> 1 sns.relplot(x = "transaction date", y = "house age", data = real_estate, dtype=float64)
#
# NameError: name 'float64' is not defined

# %%
sns.relplot(x = "distance to the nearest MRT station", y = "number of convenience stores", data = real_estate)

# %%
sns.scatterplot(x = "latitude", y = "longitude", data = real_estate);

# %%
real_estate.groupby('transaction date')['house price of unit area'].mean()
# Out:
# transaction date
# 2012    36.304762
# 2013    38.713194
# Name: house price of unit area, dtype: float64

# %%
plt.figure(figsize = (10,10))
sns.violinplot(x = "number of convenience stores", y = "house price of unit area", data = real_estate)

# %%
sns.boxplot(x = "transaction date", y = "house age", data = real_estate)

# %%
sns.relplot(x = "house age", y = "house price of unit area",hue="distance to the nearest MRT station", data = real_estate)

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x = "longitude", y = "latitude", hue = "house price of unit area",data = real_estate)

# %%
sns.heatmap(real_estate.corr(), annot=True,cmap='YlGnBu')

# %%
sns.pairplot(real_estate,diag_kind='kde')

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
sns.set(style="darkgrid")

# %%
real_estate
# Out:
#       No  transaction date  house age  distance to the nearest MRT station  \
# 0      1              2012       32.0                             84.87882
# 1      2              2012       19.5                            306.59470
# 2      3              2013       13.3                            561.98450
# 3      4              2013       13.3                            561.98450
# 4      5              2012        5.0                            390.56840
# ..   ...               ...        ...                                  ...
# 409  410              2013       13.7                           4082.01500
# 410  411              2012        5.6                             90.45606
# 411  412              2013       18.8                            390.96960
# 412  413              2013        8.1                            104.81010
# 413  414              2013        6.5                             90.45606
#
#      number of convenience stores  latitude  longitude  \
# ...

# %%
plt.figure(figsize = (10,10))
sns.swarmplot(x = "transaction date", y = "house age", data = real_estate)

# %% [markdown]
# (A) 2

# %%
real_estate.columns
# Out:
# Index(['No', 'transaction date', 'house age',
#        'distance to the nearest MRT station', 'number of convenience stores',
#        'latitude', 'longitude', 'house price of unit area'],
#       dtype='object')

# %%
model_df = real_estate[['house age','house price of unit area']]

# %%
model_df
# Out:
#      house age  house price of unit area
# 0         32.0                      37.9
# 1         19.5                      42.2
# 2         13.3                      47.3
# 3         13.3                      54.8
# 4          5.0                      43.1
# ..         ...                       ...
# 409       13.7                      15.4
# 410        5.6                      50.0
# 411       18.8                      40.6
# 412        8.1                      52.5
# 413        6.5                      63.9
#
# [414 rows x 2 columns]

# %%
x = model_df["house age"]

# %%
y = model_df["house price of unit area"]

# %%
model = LinearRegression()

# %%
model.fit(np.array(x).reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 42.4346970462629

# %%
model.coef_
# Out:
# array([-0.25148842])

# %%
model.score(np.array(x).reshape(-1,1),y)
# Out:
# 0.04433848097791171

# %%
X = real_estate[["transaction date","house age", "distance to the nearest MRT station"]]
Y = real_estate["house price of unit area"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=4)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -10048.52906130342

# %%
model.score(X_train, y_train)
# Out:
# 0.5221303607059391

# %%
model.predict(X_test)
# Out:
# array([47.45602678, 31.37846194, 32.56989053, 39.35479288, 37.25999333,
#        34.84153297, 41.35058389, 44.74560621, 42.80517956, 37.50161458,
#        32.99938803, 38.75754006, 37.6154849 , 39.79993272, 15.12748   ,
#        47.98629087, 42.12291413, 19.04503652, 23.99376853, 34.8563306 ,
#        39.87257373, 48.1004366 , 35.12349027, 48.50884623, 44.04902587,
#        43.75400012, 46.10212192, 40.51884453, 39.45439111, 39.96991424,
#        46.91457889, 36.99531035, 47.27963483, 40.5383941 , 42.87483153,
#        46.3933086 , 33.24912351, 26.37034158, 37.26289104, 36.37546692,
#        44.8922974 , 44.65407039, 39.00740875, 43.81664211, 40.61414064,
#        48.89394266, 31.57510425, 25.16051706, 37.39770665, 45.74955155,
#        35.01973131, 48.08751188, 32.08598536, 35.08469645, 41.17382708,
#        40.48466478, 43.50743819, 38.92574568, 40.40730565, 44.12075919,
#        46.88538975, 44.21785352, 30.71745276, 40.61200582, 29.15655164,
# ...

# %%
y_test.values
# Out:
# array([50.4, 28.1, 13.7, 25.3, 22.3, 40.3, 78. , 47. , 43.9, 25.6, 13.8,
#        23. , 37.7, 42.5, 18.6, 63.2, 42.3, 20.7, 24.7, 29.4, 41.5, 58.1,
#        31.5, 73.6, 37.3, 47.1, 56.3, 42.5, 38.4, 34.3, 57.8, 21.7, 54.4,
#        41. , 43.7, 44.8, 27.3, 21.8, 39.7, 38.8, 53.5, 40.3, 61.5, 49.3,
#        78.3, 63.9, 24.8, 23.8, 38.1, 45.7, 20.9, 69.7, 27. , 23.5, 37.8,
#        41. , 28.5, 36.5, 38.2, 51.4, 50.7, 40.6, 27.7, 36.2, 27.7, 40.1,
#        57.4, 71. , 46.6, 55.1, 26.5, 36.3, 42.9, 59. , 25.9, 45.5, 43.5,
#        29.5, 27.3, 42.2, 12.8, 39.5, 31.3])
