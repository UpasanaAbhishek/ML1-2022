# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/Yana Areyada/Desktop/St.Josephs/BDA02/ML Lab/kc_house_data.csv')

# %%
df
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %% [markdown]
# ### 1(a)

# %%
sns.violinplot(data = df, x = 'floors', y = 'price')
# Out:
# C:\Users\Yana Areyada\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.stripplot(data = df, x = 'price')

# %%
corr_matrix = df.corr()
corr_matrix[(corr_matrix < 0.3) & (corr_matrix > -0.3)] = 0
fig, ax = plt.subplots(figsize=(12,12))  
sns.heatmap(corr_matrix, vmax=1.0, vmin=-1.0, linewidths=0.1,
            annot_kws={"size": 9, "color": "black"}, square=True, cmap=cmap, annot=True, ax=ax)

# %%
fig_ = df.hist(figsize=(16, 20), bins=50, color="deepskyblue",
                         edgecolor="black", xlabelsize=8, ylabelsize=8)

# %%
cols = ['price', 'grade', 'sqft_living', 'bedrooms', 'sqft_basement', 'bathrooms', 'yr_built']
sns.pairplot(df[cols], size = 2.5)
plt.show()

# %%
type(df["bedrooms"][1])
# Out:
# numpy.int64

# %%
bedrooms = df["bedrooms"]

# %%
bedrooms.dtype
# Out:
# dtype('int64')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
sns.regplot(x="price", y="bedrooms", data = df)
# Out:
# C:\Users\Yana Areyada\Anaconda3\lib\site-packages\scipy\stats\stats.py:1706: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.stripplot(x="bedrooms", y="price", data=df, jitter=0.1)

# %% [markdown]
# ### 1(b)

# %%
model_df = df[['price', 'sqft_living']]

# %%
model_df
# Out:
#            price  sqft_living
# 0       221900.0         1180
# 1       538000.0         2570
# 2       180000.0          770
# 3       604000.0         1960
# 4       510000.0         1680
# 5      1225000.0         5420
# 6       257500.0         1715
# 7       291850.0         1060
# 8       229500.0         1780
# 9       323000.0         1890
# 10      662500.0         3560
# 11      468000.0         1160
# 12      310000.0         1430
# 13      400000.0         1370
# 14      530000.0         1810
# 15      650000.0         2950
# 16      395000.0         1890
# 17      485000.0         1600
# 18      189000.0         1200
# 19      230000.0         1250
# 20      385000.0         1620
# 21     2000000.0         3050
# 22      285000.0         2270
# 23      252700.0         1070
# 24      329000.0         2450
# 25      233000.0         1710
# 26      937000.0         2450
# 27      667000.0         1400
# 28      438000.0         1520
# 29      719000.0         2570
# ...

# %% [markdown]
# ### Linear Regression Model

# %%
x = model_df.price

# %%
y = model_df.sqft_living

# %%
model = LinearRegression()

# %%
model.fit(np.array(x).reshape(-1,1),y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.intercept_
# Out:
# 1131.354392713415

# %%
model.coef_
# Out:
# array([0.00175628])

# %%
model.score(np.array(x).reshape(-1,1),y)
# Out:
# 0.4928532179037931

# %% [markdown]
# ### Multiple Regression Model

# %%
df.isna().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
X = df[['bedrooms', 'floors']]
y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=4)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.intercept_
# Out:
# -37263.13932534645

# %%
model.coef_
# Out:
# array([107480.58736589, 144042.36177383])

# %%
model.score(X_train, y_train)
# Out:
# 0.13891845414382986

# %%
model.predict(X_test)
# Out:
# array([536701.57191204, 573263.34631998, 536701.57191204, ...,
#        429220.98454615, 680743.93368587, 608722.75279895])

# %%
y_test.values
# Out:
# array([311100., 535000., 271000., ..., 305000., 809000., 840000.])

# %%
model.score(X_test, model.predict(X_test))
# Out:
# 1.0

# %%
model.score(X_train, model.predict(X_train))
# Out:
# 1.0

# %%
model.score(X_test, y_test)
# Out:
# 0.1313211995629594

# %%
model.score(X_train, y_train)
# Out:
# 0.13891845414382986

# %% [markdown]
# ### 1(c) Bonus

# %%
import statsmodels.api as sm
# Out:
# C:\Users\Yana Areyada\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
x = model_df.price
y = model_df.sqft_living

# %%
x = sm.add_constant(x)

# %%
model = sm.OLS(y,x).fit()

# %%
predictionvalue = model.predict(x)

# %%
predictionvalue
# Out:
# 0        1521.072654
# 1        2076.232377
# 2        1447.484573
# 3        2192.146777
# 4        2027.056571
# 5        3282.795900
# 6        1583.596179
# 7        1643.924355
# 8        1534.420373
# 9        1698.632439
# 10       2294.889085
# 11       1953.292862
# 12       1675.800815
# 13       1833.865905
# 14       2062.182147
# 15       2272.935601
# 16       1825.084511
# 17       1983.149602
# 18       1463.291082
# 19       1535.298512
# 20       1807.521724
# 21       4643.911956
# 22       1631.893845
# 23       1575.166041
# 24       1709.170112
# 25       1540.567349
# 26       2776.987611
# 27       2302.792340
# 28       1900.604499
# 29       2394.118837
#             ...
# 21583    1833.778091
# 21584    1798.740330
# 21585    1605.549664
# 21586    2018.275177
# 21587    1807.521724
# 21588    1859.331948
# 21589    1741.661269
# 21590    3278.405203
# 21591    2135.945856
# 21592    1965.586814
# 21593    3042.185707
# 21594    1746.051966
# ...

# %%
final_model = model.summary()

# %%
print(final_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            sqft_living   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.100e+04
# Date:                Sat, 30 Apr 2022   Prob (F-statistic):               0.00
# Time:                        00:03:44   Log-Likelihood:            -1.7079e+05
# No. Observations:               21613   AIC:                         3.416e+05
# Df Residuals:                   21611   BIC:                         3.416e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1131.3544      7.914    142.952      0.000    1115.842    1146.867
# ...
