# %% [markdown]
# # Assignment1 - Machine learning
# ## 21BDA53 -MAHIKA

# %% [markdown]
# ### Question 1

# %% [markdown]
# #### Program to check legal alcohol consumption age in Maharashtra

# %%
age = int(input("Enter your age: "))
if age<20:
    print(" You are not allowed to buy alcohol in Maharashtra")
elif age==23:
    print("Congratulations!!! You are just the age to buy alcohol in Maharashtra")
else:
    print("You are old enough to buy alcohol in Maharashtra")
# Out:
# Enter your age: 23
# Congratulations!!! You are just the age to buy alcohol in Maharashtra

# %% [markdown]
# ### Question 2

# %% [markdown]
# #### Program to implement calculator

# %%
def add(x,y):
    return x+y
def subtract(x,y):
    return x-y
def multiply(x,y):
    return x*y
def power(x,y):
    return x**y
def divide(x,y):
    return x/y

# %%
a = int(input("Enter value for a : "))
b = int(input("Enter value for b : "))

print("\n1. Add\n2. Subtract\n3. Multiply\n4. Power\n5. Divide")
choice = int(input("Enter choice : "))

if choice in [1,2,3,4,5,6]:
    if choice == 1:
        value = add(a,b)
        print("Added value is : ",value)
    elif choice == 2:
        value = subtract(a,b)
        print("Subtracted value is : ",value)
    elif choice == 3:
        value = multiply(a,b)
        print("Multiplied value is : ",value)
    elif choice == 4:
        value = power(a,b)
        print("Powered value is : ",value)
    elif choice == 5:
        value = divide(a,b)
        print("Divided value is : ",value)
    elif choice == 6:
        value = modulus(a,b)
        print("Reminder value is : ",value)
else:
    print("Invalid choice!!")
# Out:
# Enter value for a : 10
# Enter value for b : 15
#
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Power
# 5. Divide
# Enter choice : 1
# Added value is :  25

# %% [markdown]
# ### Question 3

# %% [markdown]
# #### Importing relevant modules

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Read Dataset

# %%
df = pd.read_csv("AirQualityUCI.csv", delimiter=";")

# %%
df.head()
# Out:
#          Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  PT08.S2(NMHC)  \
# 0  10/03/2004  18.00.00    2,6       1360.0     150.0     11,9         1046.0
# 1  10/03/2004  19.00.00      2       1292.0     112.0      9,4          955.0
# 2  10/03/2004  20.00.00    2,2       1402.0      88.0      9,0          939.0
# 3  10/03/2004  21.00.00    2,2       1376.0      80.0      9,2          948.0
# 4  10/03/2004  22.00.00    1,6       1272.0      51.0      6,5          836.0
#
#    NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)     T    RH  \
# 0    166.0        1056.0    113.0        1692.0       1268.0  13,6  48,9
# 1    103.0        1174.0     92.0        1559.0        972.0  13,3  47,7
# 2    131.0        1140.0    114.0        1555.0       1074.0  11,9  54,0
# 3    172.0        1092.0    122.0        1584.0       1203.0  11,0  60,0
# 4    131.0        1205.0    116.0        1490.0       1110.0  11,2  59,6
#
#        AH  Unnamed: 15  Unnamed: 16
# ...

# %%
df.dtypes
# Out:
# Date              object
# Time              object
# CO(GT)            object
# PT08.S1(CO)      float64
# NMHC(GT)         float64
# C6H6(GT)          object
# PT08.S2(NMHC)    float64
# NOx(GT)          float64
# PT08.S3(NOx)     float64
# NO2(GT)          float64
# PT08.S4(NO2)     float64
# PT08.S5(O3)      float64
# T                 object
# RH                object
# AH                object
# Unnamed: 15      float64
# Unnamed: 16      float64
# dtype: object

# %%
df.shape
# Out:
# (9471, 17)

# %% [markdown]
# The dataset has 9471 rows and 17 columns

# %% [markdown]
# #### Data Cleaning

# %%
df.isna().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %% [markdown]
# It's clear that there are 2 unwanted columns and several rows which have Null values. Removing them

# %%
df.dropna(how='all', axis=1, inplace=True)
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %%
df.dropna(how = 'all', axis = 0, inplace = True)
df
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# Now the dataset has only 9357 rows and 15 columns

# %% [markdown]
# Replacing all comma to dot and coverting the columns to float values

# %%
df["CO(GT)"] = df["CO(GT)"].str.replace(",", ".").astype(float)
df["C6H6(GT)"] = df["C6H6(GT)"].str.replace(",", ".").astype(float)
df["T"] = df["T"].str.replace(",", ".").astype(float)
df["RH"] = df["RH"].str.replace(",", ".").astype(float)
df["AH"] = df["AH"].str.replace(",", ".").astype(float)
df["Time"] = df["Time"].str.replace(".", ":")
df
# Out:
# C:\Users\nakul\AppData\Local\Temp/ipykernel_11720/1465081145.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df["Time"] = df["Time"].str.replace(".", ":")
#             Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0     10/03/2004  18:00:00     2.6       1360.0     150.0      11.9
# 1     10/03/2004  19:00:00     2.0       1292.0     112.0       9.4
# 2     10/03/2004  20:00:00     2.2       1402.0      88.0       9.0
# 3     10/03/2004  21:00:00     2.2       1376.0      80.0       9.2
# 4     10/03/2004  22:00:00     1.6       1272.0      51.0       6.5
# ...          ...       ...     ...          ...       ...       ...
# 9352  04/04/2005  10:00:00     3.1       1314.0    -200.0      13.5
# 9353  04/04/2005  11:00:00     2.4       1163.0    -200.0      11.4
# ...

# %% [markdown]
# Changing to datetime format

# %%
df.Date = pd.to_datetime(df.Date)
df.Time = pd.to_datetime(df.Time)
df['Time'] = pd.Series([val.time() for val in df['Time']])
df
# Out:
#            Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0    2004-10-03  18:00:00     2.6       1360.0     150.0      11.9
# 1    2004-10-03  19:00:00     2.0       1292.0     112.0       9.4
# 2    2004-10-03  20:00:00     2.2       1402.0      88.0       9.0
# 3    2004-10-03  21:00:00     2.2       1376.0      80.0       9.2
# 4    2004-10-03  22:00:00     1.6       1272.0      51.0       6.5
# ...         ...       ...     ...          ...       ...       ...
# 9352 2005-04-04  10:00:00     3.1       1314.0    -200.0      13.5
# 9353 2005-04-04  11:00:00     2.4       1163.0    -200.0      11.4
# 9354 2005-04-04  12:00:00     2.4       1142.0    -200.0      12.4
# 9355 2005-04-04  13:00:00     2.1       1003.0    -200.0       9.5
# 9356 2005-04-04  14:00:00     2.2       1071.0    -200.0      11.9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# ...

# %% [markdown]
# #### Data description

# %%
df.describe()
# Out:
#             CO(GT)  PT08.S1(CO)     NMHC(GT)     C6H6(GT)  PT08.S2(NMHC)  \
# count  9357.000000  9357.000000  9357.000000  9357.000000    9357.000000
# mean    -34.207524  1048.990061  -159.090093     1.865683     894.595276
# std      77.657170   329.832710   139.789093    41.380206     342.333252
# min    -200.000000  -200.000000  -200.000000  -200.000000    -200.000000
# 25%       0.600000   921.000000  -200.000000     4.000000     711.000000
# 50%       1.500000  1053.000000  -200.000000     7.900000     895.000000
# 75%       2.600000  1221.000000  -200.000000    13.600000    1105.000000
# max      11.900000  2040.000000  1189.000000    63.700000    2214.000000
#
#            NOx(GT)  PT08.S3(NOx)      NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# count  9357.000000   9357.000000  9357.000000   9357.000000  9357.000000
# mean    168.616971    794.990168    58.148873   1391.479641   975.072032
# std     257.433866    321.993552   126.940455    467.210125   456.938184
# ...

# %%
import matplotlib.pyplot as plt

df.hist(figsize=(16,20), column = ["CO(GT)","PT08.S1(CO)","NMHC(GT)","C6H6(GT)","PT08.S2(NMHC)","NOx(GT)","PT08.S3(NOx)","NO2(GT)","PT08.S4(NO2)","PT08.S5(O3)","T","RH","AH"])
plt.show()

# %% [markdown]
# #### Correlation Matrix

# %%
df.corr()
# Out:
#                  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  PT08.S2(NMHC)  \
# CO(GT)         1.000000     0.041411  0.128351 -0.031378       0.029926
# PT08.S1(CO)    0.041411     1.000000  0.170007  0.852687       0.933102
# NMHC(GT)       0.128351     0.170007  1.000000  0.037323       0.110104
# C6H6(GT)      -0.031378     0.852687  0.037323  1.000000       0.767433
# PT08.S2(NMHC)  0.029926     0.933102  0.110104  0.767433       1.000000
# NOx(GT)        0.526451     0.277993 -0.004427 -0.001174       0.331272
# PT08.S3(NOx)  -0.089981     0.087019  0.048821  0.512193      -0.073667
# NO2(GT)        0.671127     0.154030  0.103307 -0.010992       0.176488
# PT08.S4(NO2)  -0.073724     0.845149  0.162680  0.774673       0.874782
# PT08.S5(O3)    0.080310     0.892434  0.101185  0.641334       0.909905
# T             -0.068939     0.754844 -0.000009  0.971375       0.669025
# RH            -0.048227     0.745375  0.008284  0.925062       0.585803
# ...

# %%
import seaborn as sns
plt.figure(figsize=(14,6))
ax = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# (T and 	C6H6(GT)), (RH and 	C6H6(GT)), (AH and 	C6H6(GT)), (AH and T), (RH and AH), (PT08.S2(NMHC) and 	PT08.S1(CO)) and (PT08.S5(O3) and PT08.S2(NMHC)) have the most positive correlation. Correlation > 0.9<br>
# (NO2(GT) and PT08.S3(NOx)) and (PT08.S3(NOx) and NOx(GT)) have the most negative correlation

# %% [markdown]
# ### Question 4

# %%
df1 = pd.read_csv("q3.csv")

# %%
df1.head()
# Out:
#     locationid  year  month   temp  latitude  longitude  stnelev  \
# 0  USS0010K01S  2000      4   5.27   39.9000  -110.7500   2773.7
# 1  CI000085406  1940      5  18.04  -18.3500   -70.3330     58.0
# 2  USC00036376  2013     12   6.22   34.3703   -91.1242     61.0
# 3  ASN00024002  1963      2  22.93  -34.2833   140.6000     65.5
# 4  ASN00028007  2001     11    NaN  -14.7803   143.5036     79.4
#
#             station countryid        country
# 0     INDIAN_CANYON        US  United States
# 1             ARICA        CI          Chile
# 2     SAINT_CHARLES        US  United States
# 3  BERRI_IRRIGATION        AS      Australia
# 4          MUSGRAVE        AS      Australia

# %%
df1[0:10]
# Out:
#     locationid  year  month   temp  latitude  longitude  stnelev  \
# 0  USS0010K01S  2000      4   5.27   39.9000  -110.7500   2773.7
# 1  CI000085406  1940      5  18.04  -18.3500   -70.3330     58.0
# 2  USC00036376  2013     12   6.22   34.3703   -91.1242     61.0
# 3  ASN00024002  1963      2  22.93  -34.2833   140.6000     65.5
# 4  ASN00028007  2001     11    NaN  -14.7803   143.5036     79.4
# 5  USW00024151  1991      4   5.59   42.1492  -112.2872   1362.5
# 6  RSM00022641  1993     12 -10.17   63.9000    38.1167     13.0
# 7  USC00470307  1943      1 -10.43   43.3333   -89.3667    317.0
# 8  FRM00007579  1996      8  21.87   44.1330     4.8330     55.0
# 9  USS0009J08S  2015      2  -2.93   40.9000  -109.9667   2773.7
#
#             station countryid        country
# 0     INDIAN_CANYON        US  United States
# 1             ARICA        CI          Chile
# 2     SAINT_CHARLES        US  United States
# 3  BERRI_IRRIGATION        AS      Australia
# ...

# %%
df1[-10::]
# Out:
#         locationid  year  month   temp  latitude  longitude  stnelev  \
# 99990  RP000098429  1995      4  29.64   14.5170   121.0000     15.0
# 99991  USR0000NWAS  1999     11   6.92   39.1500  -117.2583   2182.4
# 99992  USW00094908  1982     11   1.97   42.3978   -90.7036    321.9
# 99993  USC00200446  1952     10   5.77   43.9006   -85.8506    254.5
# 99994  ETXLT861343  1971      7  15.39    8.9800    38.8000   2324.0
# 99995  MXXLT347415  1991      4  29.02   17.7800   -96.3100     65.0
# 99996  RSM00032287  1991     11  -2.81   57.0800   156.7000      3.0
# 99997  ARM00087166  1937      4  19.42  -27.4460   -58.7620     61.9
# 99998  CA006137361  1958     10  10.02   42.7833   -81.1667    236.0
# 99999  CA006137361  1966      1  -7.85   42.7833   -81.1667    236.0
#
#                     station countryid        country
# 99990   NINOY_AQUINO_INTERN        RP    Philippines
# 99991     WASHINGTON_NEVADA        US  United States
# ...

# %%
df1.iloc[2:10]
# Out:
#     locationid  year  month   temp  latitude  longitude  stnelev  \
# 2  USC00036376  2013     12   6.22   34.3703   -91.1242     61.0
# 3  ASN00024002  1963      2  22.93  -34.2833   140.6000     65.5
# 4  ASN00028007  2001     11    NaN  -14.7803   143.5036     79.4
# 5  USW00024151  1991      4   5.59   42.1492  -112.2872   1362.5
# 6  RSM00022641  1993     12 -10.17   63.9000    38.1167     13.0
# 7  USC00470307  1943      1 -10.43   43.3333   -89.3667    317.0
# 8  FRM00007579  1996      8  21.87   44.1330     4.8330     55.0
# 9  USS0009J08S  2015      2  -2.93   40.9000  -109.9667   2773.7
#
#             station countryid        country
# 2     SAINT_CHARLES        US  United States
# 3  BERRI_IRRIGATION        AS      Australia
# 4          MUSGRAVE        AS      Australia
# 5        MALAD_CITY        US  United States
# 6             ONEGA        RS         Russia
# 7         ARLINGTON        US  United States
# 8            ORANGE        FR         France
# ...

# %%
df1.iloc[[5,2],[4,5]]
# Out:
#    latitude  longitude
# 5   42.1492  -112.2872
# 2   34.3703   -91.1242

# %%
df1.loc[:,"year"]
# Out:
# 0        2000
# 1        1940
# 2        2013
# 3        1963
# 4        2001
#          ...
# 99995    1991
# 99996    1991
# 99997    1937
# 99998    1958
# 99999    1966
# Name: year, Length: 100000, dtype: int64

# %% [markdown]
# ### Question 5

# %% [markdown]
# ###### Can we find correlation between two categorical variables? How?

# %% [markdown]
# Yes. We can have correlation between 2 categorical variables. Spearman Rank Correlation is a method to do it
