# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Real estate.csv")
df
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.tail()
# Out:
#       No  X1 transaction date  X2 house age  \
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 409                              4082.01500                                0
# 410                                90.45606                                9
# 411                               390.96960                                7
# 412                               104.81010                                5
# 413                                90.45606                                9
#
#      X5 latitude  X6 longitude  Y house price of unit area
# 409     24.94155     121.50381                        15.4
# 410     24.97433     121.54310                        50.0
# ...

# %%
df.shape
# Out:
# (414, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 414 entries, 0 to 413
# Data columns (total 8 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X1 transaction date                     414 non-null    float64
#  2   X2 house age                            414 non-null    float64
#  3   X3 distance to the nearest MRT station  414 non-null    float64
#  4   X4 number of convenience stores         414 non-null    int64
#  5   X5 latitude                             414 non-null    float64
#  6   X6 longitude                            414 non-null    float64
#  7   Y house price of unit area              414 non-null    float64
# dtypes: float64(6), int64(2)
# memory usage: 26.0 KB

# %%
df.describe()
# Out:
#                No  X1 transaction date  X2 house age  \
# count  414.000000           414.000000    414.000000
# mean   207.500000          2013.148971     17.712560
# std    119.655756             0.281967     11.392485
# min      1.000000          2012.667000      0.000000
# 25%    104.250000          2012.917000      9.025000
# 50%    207.500000          2013.167000     16.100000
# 75%    310.750000          2013.417000     28.150000
# max    414.000000          2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
# ...

# %%
df.columns
# Out:
# Index(['No', 'X1 transaction date', 'X2 house age',
#        'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
df.nunique()
# Out:
# No                                        414
# X1 transaction date                        12
# X2 house age                              236
# X3 distance to the nearest MRT station    259
# X4 number of convenience stores            11
# X5 latitude                               234
# X6 longitude                              232
# Y house price of unit area                270
# dtype: int64

# %%
# Cleaning the Data

# %%
df.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
#Checking whether there are errors or not

correlation = df.corr()

# %%
sns.set(style="darkgrid")

# %% [markdown]
# ### Heatmap

# %%
'''heatmap is a two dimensional visual representation of data where values are encoded in colors,
delivering a convenient, insightful view of information'''

sns.heatmap(correlation, xticklabels=correlation.columns, yticklabels=correlation.columns, 
            annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Pairplot

# %%
'''Pairplot visualizes the given data to find the relationship between them 
where the variables can be continous or categorical'''

sns.pairplot(df)

# %% [markdown]
# ### Relplot (Relational)

# %%
sns.relplot(x="X5 latitude", y="X6 longitude", data=df)

# %%
sns.scatterplot(x = "X5 latitude", y="X6 longitude", hue="X2 house age", data=df)
# Out:
# <AxesSubplot:xlabel='X5 latitude', ylabel='X6 longitude'>

# %%
sns.relplot(x="X1 transaction date", y="X2 house age", hue="No", data=df)

# %%
sns.scatterplot(x="X2 house age", y="Y house price of unit area", 
            hue="X4 number of convenience stores", data=df)
# Out:
# <AxesSubplot:xlabel='X2 house age', ylabel='Y house price of unit area'>

# %%
sns.relplot(x="X2 house age", y="Y house price of unit area", 
            hue="X4 number of convenience stores", style="X5 latitude", data=df)

# %%
sns.scatterplot(x = "X5 latitude", y="X6 longitude", 
                hue="X2 house age", size="X2 house age", data=df)
# Out:
# <AxesSubplot:xlabel='X5 latitude', ylabel='X6 longitude'>

# %%
sns.scatterplot(x = "X5 latitude", y="X6 longitude", hue="X2 house age", 
                size="X2 house age", data=df, sizes=(5, 50), legend="full")
# Out:
# <AxesSubplot:xlabel='X5 latitude', ylabel='X6 longitude'>

# %%
sns.scatterplot(data=df, x="X5 latitude", y="X6 longitude", s=100, color=".2", marker="+")
# Out:
# <AxesSubplot:xlabel='X5 latitude', ylabel='X6 longitude'>

# %%
sns.scatterplot(data=df, x="X5 latitude", y="X6 longitude", s=100, color=".1", marker="*")
# Out:
# <AxesSubplot:xlabel='X5 latitude', ylabel='X6 longitude'>

# %%
sns.relplot(x="X2 house age", y="Y house price of unit area", 
            hue="X4 number of convenience stores", style="X4 number of convenience stores", 
            kind="line", data=df)

# %%
df.groupby('X5 latitude')['X6 longitude'].mean()
# Out:
# X5 latitude
# 24.93207    121.51597
# 24.93293    121.51203
# 24.93363    121.51158
# 24.93885    121.50383
# 24.94155    121.50381
#               ...
# 24.99156    121.53406
# 24.99176    121.53456
# 24.99800    121.51550
# 25.00115    121.51776
# 25.01459    121.51816
# Name: X6 longitude, Length: 234, dtype: float64

# %%
sns.relplot(x = "X1 transaction date", y = "X2 house age", 
            hue = "X5 latitude", col = "X6 longitude", data = df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-27-e4453408567e> in <module>
# ----> 1 sns.relplot(x = "X1 transaction date", y = "X2 house age",
#       2             hue = "X5 latitude", col = "X6 longitude", data = df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#    1013     facet_kws = {} if facet_kws is None else facet_kws.copy()
# ...

# %% [markdown]
# ### Catplot(Categorical)

# %%
power = pd.read_csv("Power_consumption.csv")
power
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# ...

# %%
sns.stripplot(x=power["Temperature"])
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
sns.stripplot(x=power["Wind Speed"])
# Out:
# <AxesSubplot:xlabel='Wind Speed'>

# %%
sns.stripplot(x="Wind Speed", y="Humidity", data=power)
# Out:
# <AxesSubplot:xlabel='Wind Speed', ylabel='Humidity'>

# %%
sns.stripplot(x="Wind Speed", y="Humidity", data=power, jitter=0.05)
# Out:
# <AxesSubplot:xlabel='Wind Speed', ylabel='Humidity'>

# %%
sns.stripplot(x="Wind Speed", y="Humidity", data=power, jitter=0.05, linewidth = 1)
# Out:
# <AxesSubplot:xlabel='Wind Speed', ylabel='Humidity'>

# %%
sns.stripplot(x="Temperature", y="Humidity", hue="Wind Speed", data=power, jitter=0.05)

# %%
sns.stripplot(x="Wind Speed", y="Humidity", hue="diffuse flows",
                   data=power, palette="Set2", size=20, marker="D",
                   edgecolor="gray", alpha=.25)

# %%
sns.boxplot(x="Wind Speed", y="Humidity", data=power, whis=np.inf)
sns.stripplot(x="Wind Speed", y="Humidity", data=power, color=".3")

# %%
sns.violinplot(x="Humidity", y="Wind Speed", data=power, inner=None, color=".8")
sns.stripplot(x="Humidity", y="Wind Speed", data=power)
