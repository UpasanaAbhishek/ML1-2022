# %% [markdown]
# # ML 1 Lab - 02
# # Date : 23 - 04 - 2022
# # 21BDA10 - Aishwarya C S
# # 1. Explanatory Data Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
df =  pd.read_csv("laptop_price.csv")

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.sample(5)
# Out:
#       laptop_ID   Company                                    Product  \
# 718         726  Mediacom                              Smartbook 142
# 223         228        HP                                ProBook 450
# 650         658      Asus                                 ROG G701VI
# 1297       1315      Asus  X556UJ-XO044T (i7-6500U/4GB/500GB/GeForce
# 783         792    Lenovo                          IdeaPad 110-15IBR
#
#       TypeName  Inches             ScreenResolution  \
# 718   Notebook    14.0  IPS Panel Full HD 1920x1200
# 223   Notebook    15.6            Full HD 1920x1080
# 650     Gaming    17.3  IPS Panel Full HD 1920x1080
# 1297  Notebook    15.6                     1366x768
# 783   Notebook    15.6                     1366x768
#
#                                        Cpu   Ram     Memory  \
# 718               Intel Atom Z8350 1.92GHz   4GB   32GB HDD
# 223             Intel Core i5 8250U 1.6GHz   8GB    1TB HDD
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %% [markdown]
# ### There is no missing values in the given dataset.

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.corr()
# Out:
#              laptop_ID    Inches  Price_euros
# laptop_ID     1.000000 -0.087796     0.067830
# Inches       -0.087796  1.000000     0.068197
# Price_euros   0.067830  0.068197     1.000000

# %% [markdown]
# Laptop price and inches are positively correlated. But the correlation between these two variables are very less.

# %%
df['Company'].value_counts()
# Out:
# Lenovo       297
# Dell         297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Vero           4
# Xiaomi         4
# Google         3
# Fujitsu        3
# Chuwi          3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df['Company'].value_counts().plot(kind = 'bar' , x = 'Company')
# Out:
# <AxesSubplot:>

# %%
sns.set(rc = {'figure.figsize':(16,10)})

# %%
sns.barplot(x='Company' , y = 'Price_euros' , data = df)
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Price_euros'>

# %%
df['Product'].value_counts()
# Out:
# XPS 13                                       30
# Inspiron 3567                                29
# 250 G6                                       21
# Legion Y520-15IKBN                           19
# Vostro 3568                                  19
#                                              ..
# TP501UA-CJ131T (i5-7200U/8GB/1TB/W10)         1
# Predator 17                                   1
# LifeBook A557                                 1
# ZenBook UX410UA-GV183T                        1
# Q304UA-BHI5T11 (i5-7200U/6GB/1TB/FHD/W10)     1
# Name: Product, Length: 618, dtype: int64

# %%
df['TypeName'].value_counts()
# Out:
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: TypeName, dtype: int64

# %%
sns.barplot(x = 'TypeName' , y = 'Price_euros', data = df)
# Out:
# <AxesSubplot:xlabel='TypeName', ylabel='Price_euros'>

# %%
c = df['Inches'].value_counts()
c
# Out:
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 13.5      6
# 13.9      6
# 12.0      6
# 12.3      5
# 10.1      4
# 15.0      4
# 15.4      4
# 13.0      2
# 11.3      1
# 14.1      1
# 17.0      1
# 18.4      1
# Name: Inches, dtype: int64

# %%
plt.rcParams['figure.figsize'] = (5, 4)

# %%
c.plot(kind='bar', x = 'Inches')
# Out:
# <AxesSubplot:>

# %%
sns.set(rc = {'figure.figsize':(16,10)})

# %%
sns.barplot(x = 'Inches' , y = 'Price_euros' , data = df )
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='Price_euros'>

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2256x1504                              6
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# ...

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     134
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# AMD A12-Series 9700P 2.5GHz      1
# Intel Core i7 2.8GHz             1
# Intel Core M M7-6Y75 1.2GHz      1
# Intel Core i5 7200U 2.70GHz      1
# AMD E-Series 9000e 1.5GHz        1
# Name: Cpu, Length: 118, dtype: int64

# %%
c1 = df['Ram'].value_counts()
c1
# Out:
# 8GB     619
# 4GB     375
# 16GB    200
# 6GB      41
# 12GB     25
# 2GB      22
# 32GB     17
# 24GB      3
# 64GB      1
# Name: Ram, dtype: int64

# %%
df['Ram'].value_counts().plot(kind = 'bar' , x = 'Ram')
# Out:
# <AxesSubplot:>

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia GeForce GTX 980       1
# Nvidia GeForce GTX 940M      1
# AMD Radeon Pro 560           1
# AMD Radeon R9 M385           1
# Nvidia Quadro M500M          1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Windows 10 S       8
# Mac OS X           8
# Android            2
# Name: OpSys, dtype: int64

# %%
df['OpSys'].value_counts().plot(kind = 'bar' , x = 'OpSys')
# Out:
# <AxesSubplot:>

# %%
df['Weight'].value_counts()
# Out:
# 2.2kg      121
# 2.1kg       58
# 2.4kg       44
# 2.3kg       41
# 2.5kg       38
#           ...
# 3.4kg        1
# 4.7kg        1
# 3.8kg        1
# 4.0kg        1
# 2.191kg      1
# Name: Weight, Length: 179, dtype: int64

# %%
df['Price_euros'].value_counts()
# Out:
# 1099.00    14
# 1799.00    14
# 1499.00    14
# 899.00     11
# 1299.00    11
#            ..
# 1877.00     1
# 1672.00     1
# 443.99      1
# 1244.00     1
# 415.00      1
# Name: Price_euros, Length: 791, dtype: int64

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %% [markdown]
# ## Charts covered in the class

# %%
sns.set(rc = {'figure.figsize':(16,10)})

# %%
sns.boxplot(x ='Price_euros', y = 'Company', data = df)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='Company'>

# %%
sns.boxplot(x ='Price_euros', y = 'TypeName', data = df)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='TypeName'>

# %%
sns.boxplot(x = 'Price_euros' , y = 'Ram' , order = ['2GB','4GB' ,'6GB','8GB','12GB''16GB','24GB','32GB' , '64GB'] ,data = df)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='Ram'>

# %%
sns.boxplot(x = 'Price_euros' , y = 'OpSys' , data = df)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='OpSys'>

# %%
sns.set(rc = {'figure.figsize':(11.7,8.27)})

# %%
sns.relplot(x='Ram' , y = 'Price_euros' , data = df)

# %%
sns.relplot(x='Price_euros' , y = 'OpSys' , data = df)

# %%
sns.scatterplot(x = 'Price_euros' , y = 'TypeName', data = df)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='TypeName'>

# %%
sns.scatterplot(x='TypeName' , y = 'Price_euros' , data = df)
# Out:
# <AxesSubplot:xlabel='TypeName', ylabel='Price_euros'>

# %%
sns.catplot(x='Ram' , y = 'Price_euros' , data = df)

# %%
sns.swarmplot(x='TypeName' , y = 'Price_euros' , data = df)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 55.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='TypeName', ylabel='Price_euros'>

# %%
sns.boxenplot(x='Price_euros' , y = 'OpSys' , data = df)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='OpSys'>

# %%
sns.violinplot(x='Ram' , y = 'Price_euros' , data = df)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price_euros'>

# %% [markdown]
# ## 5 charts which are not done in the class

# %%
sns.displot(df , x = 'Price_euros')

# %%
sns.displot(df , x = 'Price_euros', kind = 'kde')

# %%
sns.displot(df , x = 'Price_euros', kind = 'ecdf')

# %%
sns.displot(df , x = 'Price_euros', kind = 'kde', rug = True)

# %%
sns.relplot(data = df , y = 'Price_euros',x = "TypeName" , kind = 'line')

# %%
sns.stripplot(data = df , y = 'Price_euros',x = "TypeName" )
# Out:
# <AxesSubplot:xlabel='TypeName', ylabel='Price_euros'>
