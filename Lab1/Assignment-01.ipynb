# %% [markdown]
# ### DEON S

# %% [markdown]
# 21BDA57

# %% [markdown]
# #### 1. Write a program that uses an if-else ladder.

# %%
a = 50

if (a == 20):
    print ('value of variable a is 20')

elif (a == 30):
    print ('value of variable a is 30')

elif (a == 40):
    print ('value of variable a is 40')

else:
    print ('value of variable a is greater than 40')
# Out:
# value of variable a is greater than 40

# %% [markdown]
# #### 2. Write 5 different functions and call them in one program.

# %%
def add(x,y):
    return x+y 
def subtract(x,y):
    return x-y 
def multiply(x,y):
    return x*y 
def power(x,y):
    return x**y 
def divide(x,y):
    return x/y 
def modulus(x,y):
    return x%y

a = int(input("Enter value for a : ")) 
b = int(input("Enter value for b : "))
print("\n1. Add\n2. Subtract\n3. Multiply\n4. Power\n5. Divide\n6. Modulus")

choice = int(input("Enter choice : "))
if choice in [1,2,3,4,5,6]: 
    if choice == 1:
        value = add(a,b)
        print("Added value is : ",value) 
    elif choice == 2:
        value = subtract(a,b) 
        print("Subtracted value is : ",value)
    elif choice == 3:
        value = multiply(a,b) 
        print("Multiplied value is : ",value)
    elif choice == 4: 
        value = power(a,b)
        print("Powered value is : ",value)   
    elif choice == 5:
        value = divide(a,b) 
        print("Divided value is : ",value)
    elif choice == 6:
        value = modulus(a,b) 
        print("Reminder value is : ",value)
    else:
        print("Invalid choice!!")
# Out:
# Enter value for a : 5
# Enter value for b : 8
#
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Power
# 5. Divide
# 6. Modulus
# Enter choice : 3
# Multiplied value is :  40

# %% [markdown]
# #### 3. Read any dataset from https://archive.ics.uci.edu/ml/index.php and perform a missing value treatment, check for distribution of each variable, find the correlation matrix and write conclusions from the matrix.

# %%
import pandas as pd

# %%
df=pd.read_csv('Tetuan City power consumption.csv')

# %%
df
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# ...

# %%
df.shape
# Out:
# (52416, 9)

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %%
df.tail()
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
#        Zone 2  Power Consumption  Zone 3  Power Consumption
# 52411                26857.31820                14780.31212
# 52412                26124.57809                14428.81152
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   DateTime                   52416 non-null  object
#  1   Temperature                52416 non-null  float64
#  2   Humidity                   52416 non-null  float64
#  3   Wind Speed                 52416 non-null  float64
#  4   general diffuse flows      52416 non-null  float64
#  5   diffuse flows              52416 non-null  float64
#  6   Zone 1 Power Consumption   52416 non-null  float64
#  7   Zone 2  Power Consumption  52416 non-null  float64
#  8   Zone 3  Power Consumption  52416 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.6+ MB

# %%
df.dtypes
# Out:
# DateTime                      object
# Temperature                  float64
# Humidity                     float64
# Wind Speed                   float64
# general diffuse flows        float64
# diffuse flows                float64
# Zone 1 Power Consumption     float64
# Zone 2  Power Consumption    float64
# Zone 3  Power Consumption    float64
# dtype: object

# %% [markdown]
# #### Checking the missing values

# %%
df.isna().sum()
# Out:
# DateTime                     0
# Temperature                  0
# Humidity                     0
# Wind Speed                   0
# general diffuse flows        0
# diffuse flows                0
# Zone 1 Power Consumption     0
# Zone 2  Power Consumption    0
# Zone 3  Power Consumption    0
# dtype: int64

# %% [markdown]
# It was observed that, no null values were found in the data.

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


df.hist(figsize=(16,10))
plt.show()

# %% [markdown]
# There are no null values present in the dataset.

# %%
print("\t \t \t \t \t \t CORRELATION MATRIX \t \t \t")
a=df.corr()
a
# Out:
# 	 	 	 	 	 	 CORRELATION MATRIX
#                            Temperature  Humidity  Wind Speed  \
# Temperature                   1.000000 -0.460243    0.477109
# Humidity                     -0.460243  1.000000   -0.135853
# Wind Speed                    0.477109 -0.135853    1.000000
# general diffuse flows         0.460294 -0.468138    0.133733
# diffuse flows                 0.196522 -0.256886   -0.000972
# Zone 1 Power Consumption      0.440221 -0.287421    0.167444
# Zone 2  Power Consumption     0.382428 -0.294961    0.146413
# Zone 3  Power Consumption     0.489527 -0.233022    0.278641
#
#                            general diffuse flows  diffuse flows  \
# Temperature                             0.460294       0.196522
# Humidity                               -0.468138      -0.256886
# Wind Speed                              0.133733      -0.000972
# general diffuse flows                   1.000000       0.564718
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize = (15,8))
ax = sns.heatmap(a, annot=True)

# %% [markdown]
# Zone 1,2,3 Power Consumptions are correalted.

# %%
df.describe()
# Out:
#         Temperature      Humidity    Wind Speed  general diffuse flows  \
# count  52416.000000  52416.000000  52416.000000           52416.000000
# mean      18.810024     68.259518      1.959489             182.696614
# std        5.815476     15.551177      2.348862             264.400960
# min        3.247000     11.340000      0.050000               0.004000
# 25%       14.410000     58.310000      0.078000               0.062000
# 50%       18.780000     69.860000      0.086000               5.035500
# 75%       22.890000     81.400000      4.915000             319.600000
# max       40.010000     94.800000      6.483000            1163.000000
#
#        diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# count   52416.000000              52416.000000               52416.000000
# mean       75.028022              32344.970564               21042.509082
# std       124.210949               7130.562564                5201.465892
# ...

# %% [markdown]
# #### 4. Read a dataset and perform slice it in different ways (Hint: https://pandas.pydata.org/docs/user_guide/indexing.html)

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %%
df.columns
# Out:
# Index(['DateTime', 'Temperature', 'Humidity', 'Wind Speed',
#        'general diffuse flows', 'diffuse flows', 'Zone 1 Power Consumption',
#        'Zone 2  Power Consumption', 'Zone 3  Power Consumption'],
#       dtype='object')

# %%
new_list = ['Zone 1 Power Consumption',
       'Zone 2  Power Consumption', 'Zone 3  Power Consumption']
df[new_list]
# Out:
#        Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0                   34055.69620                16128.87538
# 1                   29814.68354                19375.07599
# 2                   29128.10127                19006.68693
# 3                   28228.86076                18361.09422
# 4                   27335.69620                17872.34043
# ...                         ...                        ...
# 52411               31160.45627                26857.31820
# 52412               30430.41825                26124.57809
# 52413               29590.87452                25277.69254
# 52414               28958.17490                24692.23688
# 52415               28349.80989                24055.23167
#
#        Zone 3  Power Consumption
# 0                    20240.96386
# 1                    20131.08434
# 2                    19668.43373
# 3                    18899.27711
# 4                    18442.40964
# ...                          ...
# ...

# %%
df['general diffuse flows']
# Out:
# 0        0.051
# 1        0.070
# 2        0.062
# 3        0.091
# 4        0.048
#          ...
# 52411    0.040
# 52412    0.051
# 52413    0.084
# 52414    0.066
# 52415    0.062
# Name: general diffuse flows, Length: 52416, dtype: float64

# %%
df[3:10]
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
# 5  1/1/2017 0:50        5.853      76.9       0.081                  0.059
# 6  1/1/2017 1:00        5.641      77.7       0.080                  0.048
# 7  1/1/2017 1:10        5.496      78.2       0.085                  0.055
# 8  1/1/2017 1:20        5.678      78.1       0.081                  0.066
# 9  1/1/2017 1:30        5.491      77.3       0.082                  0.062
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
# 5          0.108               26624.81013                17416.41337
# 6          0.096               25998.98734                16993.31307
# ...

# %%
df1 = df.iloc[0:5]

# %%
df1
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %%
df2 = df.iloc[:,0:2]

# %%
df2
# Out:
#                DateTime  Temperature
# 0         1/1/2017 0:00        6.559
# 1         1/1/2017 0:10        6.414
# 2         1/1/2017 0:20        6.313
# 3         1/1/2017 0:30        6.121
# 4         1/1/2017 0:40        5.921
# ...                 ...          ...
# 52411  12/30/2017 23:10        7.010
# 52412  12/30/2017 23:20        6.947
# 52413  12/30/2017 23:30        6.900
# 52414  12/30/2017 23:40        6.758
# 52415  12/30/2017 23:50        6.580
#
# [52416 rows x 2 columns]

# %%
df.iloc[[1,3],[2,8]]
# Out:
#    Humidity  Zone 3  Power Consumption
# 1      74.5                20131.08434
# 3      75.0                18899.27711

# %%
df.loc[:,"Temperature"]
# Out:
# 0        6.559
# 1        6.414
# 2        6.313
# 3        6.121
# 4        5.921
#          ...
# 52411    7.010
# 52412    6.947
# 52413    6.900
# 52414    6.758
# 52415    6.580
# Name: Temperature, Length: 52416, dtype: float64

# %% [markdown]
# #### 5. Bonus: Can we find correlation between two categorical variables? How?

# %% [markdown]
# Checking if two categorical variables are independent can be done with Chi-Squared test of independence.(A chi-square test is a statistical test used to compare observed results with expected results. The purpose of this test is to determine if a difference between observed data and expected data is due to chance, or if it is due to a relationship between the variables you are studying)
#
# This is a typical Chi-Square test: if we assume that two variables are independent, then the values of the contingency table for these variables should be distributed uniformly. And then we check how far away from uniform the actual values are.
