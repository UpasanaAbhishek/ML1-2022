# %% [markdown]
# # QUESTION A

# %% [markdown]
# # 1) Perform EDA and upload the notebook. Along with the charts we have covered, create 5 types of charts which were not done in class (refer Seaborn documentation).

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %% [markdown]
# Required Packages : Numpy, Sklearn, Scipy, Pandas, Matplotlib, Seaborn

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")  #to change theme

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})  # to change the figure size of a seaborn axes or figure level plot

# %%
#car = sns.load_dataset("car_crashes") 
#sns.load_dataset loads an example dataset from the online repository

# %%
#sns.get_dataset_names()

# %%
import pandas as pd

# %%
cars = pd.read_csv("car.csv")

# %% [markdown]
# # Know the Data

# %%
cars.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# This dataset contains information about used cars.

# %% [markdown]
# The columns in the given dataset are as follows:
#
# name ||
# year ||
# selling_price ||
# km_driven ||
# fuel ||
# seller_type||
# transmission ||
# Owner

# %%
cars.sample(6)  #Return a random sample of items from an axis of object.
# Out:
#                                        name  year  selling_price  km_driven  \
# 3760                     Toyota Etios 1.5 V  2011         285000      45500
# 1755  Toyota Innova 2.5 G (Diesel) 8 Seater  2012         600000     145000
# 3824                Hyundai EON D Lite Plus  2017         350000      20000
# 1043                 Mahindra XUV500 W8 2WD  2013         950000      49700
# 1665          Chevrolet Optra Magnum 2.0 LT  2008         210000      90000
# 2386                 Fiat Punto 1.3 Emotion  2010         190000     120000
#
#         fuel seller_type transmission                 owner     mileage  \
# 3760  Petrol      Dealer       Manual           First Owner  16.78 kmpl
# 1755  Diesel  Individual       Manual          Second Owner  12.99 kmpl
# 3824  Petrol  Individual       Manual           First Owner   21.1 kmpl
# 1043  Diesel  Individual       Manual           First Owner   15.1 kmpl
# 1665  Diesel  Individual       Manual  Fourth & Above Owner  16.52 kmpl
# ...

# %%
cars['year'].value_counts()
# Out:
# 2017    1018
# 2016     859
# 2018     807
# 2015     776
# 2013     670
# 2012     651
# 2014     621
# 2011     592
# 2019     583
# 2010     394
# 2009     246
# 2008     214
# 2007     183
# 2006     124
# 2005      97
# 2020      74
# 2004      62
# 2003      49
# 2002      27
# 2000      22
# 1999      18
# 1997      11
# 2001      10
# 1998      10
# 1996       3
# 1994       3
# 1995       2
# 1983       1
# 1991       1
# Name: year, dtype: int64

# %%
cars['owner'].value_counts()
# Out:
# First Owner             5289
# Second Owner            2105
# Third Owner              555
# Fourth & Above Owner     174
# Test Drive Car             5
# Name: owner, dtype: int64

# %%
cars['seller_type'].value_counts()
# Out:
# Individual          6766
# Dealer              1126
# Trustmark Dealer     236
# Name: seller_type, dtype: int64

# %%
cars['seats'].value_counts()
# Out:
# 5.0     6254
# 7.0     1120
# 8.0      236
# 4.0      133
# 9.0       80
# 6.0       62
# 10.0      19
# 2.0        2
# 14.0       1
# Name: seats, dtype: int64

# %%
cars.info()  #Print a concise summary of a DataFrame.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
cars.describe()  #Generate descriptive statistics.
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
cars.corr()
# Out:
#                    year  selling_price  km_driven     seats
# year           1.000000       0.414092  -0.418006 -0.009144
# selling_price  0.414092       1.000000  -0.225534  0.041358
# km_driven     -0.418006      -0.225534   1.000000  0.227336
# seats         -0.009144       0.041358   0.227336  1.000000

# %%
cars.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %% [markdown]
# Data Cleaning

# %%
missing_report = cars.isnull().sum().reset_index().assign(
    misisng_percentage=lambda x: x[0]/cars.shape[0]
).sort_values(by="misisng_percentage", ascending=False).rename(columns={
"index": "column name", 0: "missing row count", "misisng_percentage" : "missing percentage"
})
missing_report = missing_report[missing_report['missing percentage']>0]
missing_report
# Out:
#    column name  missing row count  missing percentage
# 11      torque                222            0.027313
# 8      mileage                221            0.027190
# 9       engine                221            0.027190
# 12       seats                221            0.027190
# 10   max_power                215            0.026452

# %% [markdown]
# Since the missing percentage for all columns are less than 0.03, we drop the missing values

# %%
cars.dropna(inplace = True)

# %%
cars.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 864.7+ KB

# %%
cars['mileage'] = cars['mileage'].str.replace('kmpl', '')

# %%
cars['mileage'] = cars['mileage'].str.replace('km/kg', '')

# %%
cars['engine'] = cars['engine'].str.replace('CC', '')

# %%
cars['max_power'] = cars['max_power'].str.replace('bhp', '')

# %%
cars.sample(15)
# Out:
#                                       name  year  selling_price  km_driven  \
# 6378           Maruti Wagon R VXI Optional  2017         390000      25000
# 2185        Mahindra Bolero Power Plus SLX  2017         690000      60000
# 6322                 Maruti Alto LXi BSIII  2007         140000      35000
# 3864                 Honda Amaze VX i-DTEC  2013         350000     140000
# 5041                Mahindra Thar CRDe ABS  2019         974000      15000
# 3079                         Lexus ES 300h  2019        5150000      20000
# 7980                   Maruti Alto 800 LXI  2018         300000      30000
# 5000                Honda Mobilio S i DTEC  2015         670000     120000
# 4909                  Ford Figo Diesel ZXI  2011         160000      85000
# 6284                Maruti Ertiga SHVS VDI  2019         925000      50000
# 3047  Toyota Innova 2.5 G4 Diesel 8-seater  2010         450000     210000
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7906 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           7906 non-null   object
#  1   year           7906 non-null   int64
#  2   selling_price  7906 non-null   int64
#  3   km_driven      7906 non-null   int64
#  4   fuel           7906 non-null   object
#  5   seller_type    7906 non-null   object
#  6   transmission   7906 non-null   object
#  7   owner          7906 non-null   object
#  8   mileage        7906 non-null   object
#  9   engine         7906 non-null   object
#  10  max_power      7906 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7906 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 864.7+ KB

# %%
cars['mileage']=cars['mileage'].astype('float64')

# %%
cars['engine']=cars['engine'].astype('int64')

# %%
cars['max_power']=cars['max_power'].astype('float64')

# %%
cars['seats']=cars['seats'].astype('int64')

# %%
cars.sample(15)
# Out:
#                                        name  year  selling_price  km_driven  \
# 4244               Maruti Swift AMT VVT VXI  2019         650000       5621
# 1748        Toyota Fortuner 2.8 4WD AT BSIV  2017        2950000      50000
# 2634         Volvo XC40 D4 Inscription BSIV  2019        3800000      20000
# 1392            Mahindra Bolero DI AC BSIII  2005         250000      80000
# 1009              Ford Figo Diesel Titanium  2012         425000      81632
# 2413          Chevrolet Captiva 2.2 LTZ AWD  2012         700000      50000
# 6506                        Maruti Ritz VDi  2012         220000      70000
# 1279                  Maruti Swift VDI BSIV  2014         400000      90000
# 6922                       Maruti Swift VXI  2019         610000      18000
# 5345                     Maruti Celerio LXI  2014         300000      80000
# 2331  Chevrolet Tavera Neo 3 10 Seats BSIII  2014         600000     110000
# ...

# %%
cars.drop_duplicates(inplace = True)

# %%
cars.to_csv("cars_cleaned.csv")

# %% [markdown]
# # Visualize the Data

# %% [markdown]
# Relational Plots relplot() - Figure-level interface for drawing relational plots onto a FacetGrid.
#
# This function provides access to several different axes-level functions that show the relationship between two variables with semantic mappings of subsets.

# %%
sns.relplot(x = "mileage", y = "selling_price", data = cars)

# %%
sns.relplot(x = "mileage", y = "selling_price",hue = "fuel", data = cars)

# %%
sns.relplot(x = "mileage", y = "km_driven",hue = "fuel" ,data = cars, palette = ['darkblue','green','orange','yellow'])

# %%
sns.relplot(x = "selling_price",y = "mileage",hue = "fuel", style = "seller_type",height = 6,data = cars);

# %%
sns.relplot(x = "selling_price",y = "mileage",hue = "seats",height = 6,data = cars);

# %%
sns.relplot(x = "selling_price",y = "mileage",hue = "seats",size = "seats",sizes = (10,300),data = cars)

# %%
sns.relplot(x = "mileage", y = "selling_price", hue = "fuel", col = "seller_type", data = cars);

# %%
cars.groupby('seller_type')['selling_price'].mean()
# Out:
# seller_type
# Dealer              936708.656156
# Individual          480162.313579
# Trustmark Dealer    718111.111111
# Name: selling_price, dtype: float64

# %%
cars.groupby('seller_type')['selling_price'].count()
# Out:
# seller_type
# Dealer               666
# Individual          6024
# Trustmark Dealer      27
# Name: selling_price, dtype: int64

# %%
sns.relplot(x = "mileage", y = "selling_price", hue = "fuel", col = "transmission", data = cars);

# %%
cars.groupby('transmission')['selling_price'].mean()
# Out:
# transmission
# Automatic    1.322916e+06
# Manual       4.518166e+05
# Name: selling_price, dtype: float64

# %%
cars.groupby('transmission')['mileage'].mean()
# Out:
# transmission
# Automatic    17.169078
# Manual       19.681672
# Name: mileage, dtype: float64

# %% [markdown]
# Scatter plots scatterplot() - Draw a scatter plot with possibility of several semantic groupings.
#
# The relationship between x and y can be shown for different subsets of the data using the hue, size, and style parameters. These parameters control what visual semantics are used to identify the different subsets. It is possible to show up to three dimensions independently by using all three semantic types, but this style of plot can be hard to interpret and is often ineffective.

# %%
sns.scatterplot(x = "mileage", y = "selling_price", hue= "fuel", data = cars)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='selling_price'>

# %%
sns.scatterplot(x = "mileage", y = "selling_price", hue= "fuel", style = "fuel",data = cars)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='selling_price'>

# %% [markdown]
# Categorical Plots

# %% [markdown]
# catplot() - Figure-level interface for drawing categorical plots onto a FacetGrid.
#
# This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.

# %%
sns.catplot(x = "transmission", y = "km_driven", data = cars)

# %%
sns.catplot(x = "transmission", y = "mileage", hue = "fuel",data = cars)

# %%
sns.catplot(x = "transmission", y = "mileage", hue = "fuel",jitter =True,alpha = 0.02,data = cars)

# %%
sns.catplot(x = "transmission", y = "mileage", hue = "fuel",jitter =False,alpha = 0.02,data = cars)

# %% [markdown]
# Bee Swarm Plot swarmplot() - Draw a categorical scatterplot with non-overlapping points.
#
# This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations.

# %%
sns.swarmplot(x = "transmission", y = "max_power",data = cars)
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 81.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:1296: UserWarning: 5.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='transmission', ylabel='max_power'>

# %%
#The same plot with decreased size of marker

# %%
sns.swarmplot(x = "transmission", y = "max_power",size = 0.5,data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='max_power'>

# %%
sns.swarmplot(x = "fuel", y = "selling_price", hue = "transmission", size = 0.8 ,data = cars)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %% [markdown]
# stripplot() - Draw a scatterplot where one variable is categorical.
#
# A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.

# %%
sns.stripplot(x = "transmission", y = "max_power",size = 3,data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='max_power'>

# %%
sns.stripplot(x = "fuel", y = "selling_price", hue = "transmission", data = cars)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='selling_price'>

# %% [markdown]
# Box Plots boxplot() - Draw a box plot to show distributions with respect to categories.
#
# A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
sns.boxplot(x = "fuel", y = "mileage", data = cars)
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='mileage'>

# %%
sns.boxplot(x = "transmission", y = "selling_price", hue = "owner", data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
sns.boxplot(x = "owner", y = "selling_price", hue = "transmission", data = cars)
# Out:
# <AxesSubplot:xlabel='owner', ylabel='selling_price'>

# %%
sns.boxplot(x = "year", y = "fuel", hue = "transmission", data = cars)
# Out:
# <AxesSubplot:xlabel='year', ylabel='fuel'>

# %%
sns.boxplot(x = "mileage", y = "fuel", hue = "transmission", data = cars)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='fuel'>

# %%
sns.boxplot(x = "transmission", y = "mileage", data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='mileage'>

# %%
sns.boxplot(x = "transmission", y = "selling_price", data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %% [markdown]
# Boxen Plot boxenplot() - Draw an enhanced box plot for larger datasets.
#
# This style of plot was originally named a “letter value” plot because it shows a large number of quantiles that are defined as “letter values”. It is similar to a box plot in plotting a nonparametric representation of a distribution in which all features correspond to actual observations. By plotting more quantiles, it provides more information about the shape of the distribution, particularly in the tails.

# %%
sns.boxenplot(x= "transmission", y = "selling_price", hue = "fuel", data =cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
sns.boxenplot(x = "year", y = "fuel", hue = "transmission", data = cars)
# Out:
# <AxesSubplot:xlabel='year', ylabel='fuel'>

# %% [markdown]
# Fancy Box Plot

# %% [markdown]
# violinplot() - Draw a combination of boxplot and kernel density estimate.
#
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
sns.violinplot(x ="year", y = "fuel", hue = "transmission", data = cars)
# Out:
# <AxesSubplot:xlabel='year', ylabel='fuel'>

# %%
sns.violinplot(x ="seller_type", y = "selling_price", hue = "transmission",bw = 0.55, data = cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
sns.violinplot(x ="seller_type", y = "selling_price", hue = "transmission",bw = 0.55,split = True, data = cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
sns.violinplot(x ="seller_type", y = "selling_price", hue = "transmission",bw = 0.15,split = True,palette= "pastel", inner= "point", data = cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
sns.violinplot(x ="seller_type", y = "selling_price", hue = "transmission",bw = 0.55,split = True,palette= "pastel", inner= "box", data = cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
sns.violinplot(x ="seller_type", y = "selling_price", hue = "transmission",bw = 0.55,split = True,palette= "pastel", inner= "quartile", data = cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
sns.violinplot(x ="seller_type", y = "selling_price", inner = None, data = cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %% [markdown]
# Overlap two kind of plots

# %%
sns.violinplot(x = "transmission", y = "selling_price", inner = None, data = cars)
sns.swarmplot(x = "transmission", y = "selling_price", color = "k", size = 0.3, data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
sns.violinplot(x = "seller_type", y = "selling_price", inner = None, data = cars)
sns.swarmplot(x = "seller_type", y = "selling_price", color = "k", size = 0.3, data = cars);

# %% [markdown]
# Bar Plot - Show point estimates and confidence intervals as rectangular bars.
#
# A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars. Bar plots include 0 in the quantitative axis range, and they are a good choice when 0 is a meaningful value for the quantitative variable, and you want to make comparisons against it.

# %%
sns.barplot(x = "transmission", y= "selling_price", hue = "fuel", data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %%
sns.barplot(x = "transmission", y= "selling_price", hue = "fuel", palette = "ch:.25", data = cars)
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='selling_price'>

# %% [markdown]
# Bars by categories

# %% [markdown]
# countplot() - Show the counts of observations in each categorical bin using bars.
#
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.

# %%
sns.countplot(x = "seller_type", hue ="fuel", data = cars);

# %%
sns.countplot(x = "seller_type", hue ="fuel", palette = "ch:.25",data = cars);

# %%
sns.countplot(x = "seller_type", hue ="seats", palette = "ch:.62",data = cars);

# %% [markdown]
# Point plots pointplot() - Show point estimates and confidence intervals using scatter plot glyphs.
#
# A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.
#
# Point plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables. They are particularly adept at showing interactions: how the relationship between levels of one categorical variable changes across levels of a second categorical variable.

# %%
sns.pointplot(x = "seller_type", y = "selling_price", data= cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
sns.pointplot(x = "seller_type", y = "selling_price", hue = "transmission", linestyles = ["-", "--"], data= cars)
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='selling_price'>

# %%
f, ax = plt.subplots(figsize = (15,5))
sns.countplot(x = "owner", hue= "transmission", data = cars)
# Out:
# <AxesSubplot:xlabel='owner', ylabel='count'>

# %%
sns.catplot(x="fuel", y = "owner", hue = "seats", col = "transmission", data = cars)

# %% [markdown]
# Some other charts in Seaborn:

# %% [markdown]
# 1. distplot() - Flexibly plot a univariate distribution of observations.

# %%
sns.distplot(cars['selling_price'],bins = None, hist = True, kde = True, rug = False)
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.distplot(cars['mileage'],bins = None, hist = False, kde = True, rug = True)
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='mileage', ylabel='Density'>

# %% [markdown]
# This function is deprecated and will be removed in a future version. Instead we adapt the code to the following 2 functions : displot() and histplot()

# %% [markdown]
# 2. displot() - a figure-level function with a similar flexibility over the kind of plot to draw
#
# This function provides access to several approaches for visualizing the univariate or bivariate distribution of data, including subsets of data defined by semantic mapping and faceting across multiple subplots.

# %%
sns.displot(data = cars, x = cars['mileage'], y = cars['selling_price'], row = cars['transmission'],kind = 'hist',hue = cars['fuel'])

# %%
sns.displot(data = cars, x = cars['mileage'], y = cars['max_power'], col = cars['transmission'],kind = 'kde', hue = cars['fuel'])
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:1210: UserWarning: No contour levels were found within the data range.
#   cset = contour_func(

# %% [markdown]
# 3. histplot() -  an axes-level function for plotting histograms, including with kernel density smoothing
#
# This function provides access to several approaches for visualizing the univariate or bivariate distribution of data, including subsets of data defined by semantic mapping and faceting across multiple subplots.

# %%
sns.histplot(data = cars, x = "seats")
# Out:
# <AxesSubplot:xlabel='seats', ylabel='Count'>

# %%
sns.histplot(data = cars, x = cars['mileage'], y = cars['selling_price'], hue = cars['fuel'], stat = 'probability')
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='selling_price'>

# %%
sns.histplot(data = cars, x="max_power", hue="fuel", element="step")
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='Count'>

# %%
sns.histplot(data = cars, x="max_power", hue="fuel", element="poly")
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='Count'>

# %%
sns.histplot(cars, x="year", y="selling_price",bins=100, discrete=True, log_scale=(False, True),thresh=None)
# Out:
# <AxesSubplot:xlabel='year', ylabel='selling_price'>

# %% [markdown]
# 4. kdeplot() - Plot univariate or bivariate distributions using kernel density estimation.
#
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analagous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
type(cars["selling_price"][1])
# Out:
# numpy.int64

# %%
sns.kdeplot(data = cars, x = "selling_price")
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.kdeplot(data = cars, x = "selling_price", bw_adjust = .1)
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.kdeplot(data = cars, x = "selling_price", bw_adjust = 5, cut = 0)
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.kdeplot(data = cars, x = "mileage", hue = "transmission", multiple="stack")
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Density'>

# %%
sns.kdeplot(data = cars, x = "mileage", hue = "transmission", multiple="stack", bw_adjust = 5)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Density'>

# %%
sns.kdeplot(data = cars, x = "mileage", hue = "transmission", multiple="fill")
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Density'>

# %%
sns.kdeplot(data=cars, x="mileage", hue="fuel",fill=True, common_norm=False, palette="crest",alpha=.5, linewidth=0,)
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Density'>

# %% [markdown]
# 5. ecdfplot() - Plot empirical cumulative distribution functions.
#
# An ECDF represents the proportion or count of observations falling below each unique value in a dataset. Compared to a histogram or density plot, it has the advantage that each observation is visualized directly, meaning that there are no binning or smoothing parameters that need to be adjusted. It also aids direct comparisons between multiple distributions. A downside is that the relationship between the appearance of the plot and the basic properties of the distribution (such as its central tendency, variance, and the presence of any bimodality) may not be as intuitive.

# %%
sns.ecdfplot(data=cars, x="max_power")
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='Proportion'>

# %%
sns.ecdfplot(data=cars, x="engine")
# Out:
# <AxesSubplot:xlabel='engine', ylabel='Proportion'>

# %%
sns.ecdfplot(data=cars, x="selling_price", hue="fuel")
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Proportion'>

# %% [markdown]
# 6. jointplot() - Draw a plot of two variables with bivariate and univariate graphs.

# %%
sns.jointplot(data=cars, x="mileage", y="max_power", hue = "transmission")

# %%
sns.jointplot(data=cars, x="mileage", y="max_power", hue = "transmission", kind = "kde")

# %%
sns.jointplot(data=cars, x="mileage", y="max_power", kind = "hex")

# %%
sns.jointplot(data=cars, x="mileage", y="max_power", kind = "reg")

# %% [markdown]
# # 2) Fit one SLR and one MLR model using sklearn. Check if the assumptions of LR have been met.

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
sns.set(style="darkgrid")

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
sns.regplot(x="km_driven", y="selling_price", data = cars)
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='selling_price'>

# %% [markdown]
# # SIMPLE LINEAR REGRESSION

# %% [markdown]
# y=mX+c

# %% [markdown]
# y=b0+b1X1

# %%
cars
# Out:
#                                    name  year  selling_price  km_driven  \
# 0                Maruti Swift Dzire VDI  2014         450000     145500
# 1          Skoda Rapid 1.5 TDI Ambition  2014         370000     120000
# 2              Honda City 2017-2020 EXi  2006         158000     140000
# 3             Hyundai i20 Sportz Diesel  2010         225000     127000
# 4                Maruti Swift VXI BSIII  2007         130000     120000
# ...                                 ...   ...            ...        ...
# 8121  Maruti Wagon R VXI BS IV with ABS  2013         260000      50000
# 8122         Hyundai i20 Magna 1.4 CRDi  2014         475000      80000
# 8123                  Hyundai i20 Magna  2013         320000     110000
# 8124              Hyundai Verna CRDi SX  2007         135000     119000
# 8125             Maruti Swift Dzire ZDi  2009         382000     120000
#
#         fuel seller_type transmission                 owner  mileage  engine  \
# ...

# %%
cars.corr()
# Out:
#                    year  selling_price  km_driven   mileage    engine  \
# year           1.000000       0.427335  -0.387918  0.366048 -0.019763
# selling_price  0.427335       1.000000  -0.161265 -0.108655  0.442772
# km_driven     -0.387918      -0.161265   1.000000 -0.196419  0.253460
# mileage        0.366048      -0.108655  -0.196419  1.000000 -0.579153
# engine        -0.019763       0.442772   0.253460 -0.579153  1.000000
# max_power      0.159889       0.692323   0.041770 -0.378609  0.683506
# seats          0.025021       0.158531   0.207890 -0.459188  0.658711
#
#                max_power     seats
# year            0.159889  0.025021
# selling_price   0.692323  0.158531
# km_driven       0.041770  0.207890
# mileage        -0.378609 -0.459188
# engine          0.683506  0.658711
# max_power       1.000000  0.259028
# seats           0.259028  1.000000

# %%
cars.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %%
model_cars = cars[['engine', 'selling_price']]

# %%
model_cars
# Out:
#       engine  selling_price
# 0       1248         450000
# 1       1498         370000
# 2       1497         158000
# 3       1396         225000
# 4       1298         130000
# ...      ...            ...
# 8121     998         260000
# 8122    1396         475000
# 8123    1197         320000
# 8124    1493         135000
# 8125    1248         382000
#
# [6717 rows x 2 columns]

# %%
x = model_cars.engine
#X usually means our input variables (or independent variables)
y = model_cars.selling_price
#Y usually means our output/dependent variable

# %%
x
# Out:
# 0       1248
# 1       1498
# 2       1497
# 3       1396
# 4       1298
#         ...
# 8121     998
# 8122    1396
# 8123    1197
# 8124    1493
# 8125    1248
# Name: engine, Length: 6717, dtype: int64

# %%
y
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 8121    260000
# 8122    475000
# 8123    320000
# 8124    135000
# 8125    382000
# Name: selling_price, Length: 6717, dtype: int64

# %%
model = LinearRegression()

# %%
model.fit(np.array(x).reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
model.intercept_ #Intercept is b0
# Out:
# -145837.63618041168

# %%
model.coef_ #Coeffecient is b1
# Out:
# array([469.76259759])

# %%
model.score(np.array(x).reshape(-1,1),y)
# Out:
# 0.19604686299805962

# %% [markdown]
# # MULTIPLE LINEAR REGRESSION

# %%
cars.corr()
# Out:
#                    year  selling_price  km_driven   mileage    engine  \
# year           1.000000       0.427335  -0.387918  0.366048 -0.019763
# selling_price  0.427335       1.000000  -0.161265 -0.108655  0.442772
# km_driven     -0.387918      -0.161265   1.000000 -0.196419  0.253460
# mileage        0.366048      -0.108655  -0.196419  1.000000 -0.579153
# engine        -0.019763       0.442772   0.253460 -0.579153  1.000000
# max_power      0.159889       0.692323   0.041770 -0.378609  0.683506
# seats          0.025021       0.158531   0.207890 -0.459188  0.658711
#
#                max_power     seats
# year            0.159889  0.025021
# selling_price   0.692323  0.158531
# km_driven       0.041770  0.207890
# mileage        -0.378609 -0.459188
# engine          0.683506  0.658711
# max_power       1.000000  0.259028
# seats           0.259028  1.000000

# %%
x = cars[['km_driven','mileage','engine','max_power']]
y = cars['selling_price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=4)

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -1026967.1563713489

# %%
model.coef_
# Out:
# array([-1.55322387e+00,  2.43544324e+04,  1.28098484e+02,  1.15260741e+04])

# %%
model.predict(x_test)
# Out:
# array([1121057.88716138,  451536.89565245,  426753.85750276, ...,
#         -82415.84055079,  233240.43545784,  841417.08743534])

# %%
y_test.values
# Out:
# array([1400000,  300000,  425000, ...,  160000,  325000,  670000])

# %%
model.score(x_test, model.predict(x_test))
# Out:
# 1.0

# %%
model.score(x_train, model.predict(x_train))
# Out:
# 1.0

# %%
model.score(x_test, y_test)
# Out:
# 0.5280528666522171

# %%
model.score(x_train, y_train)
# Out:
# 0.5420887891696365

# %% [markdown]
# BONUS - statsmodel package

# %%
from pandas import DataFrame
import statsmodels.api as sm

# %% [markdown]
# SIMPLE LINEAR REGRESSION

# %%
x = model_cars.engine
y = model_cars.selling_price

# %%
x = sm.add_constant(x)
# Out:
# /Users/user/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
model = sm.OLS(y, x).fit() # sm.OLS(output, input)

# %% [markdown]
# OLS stands for Ordinary Least Squares and the method “Least Squares” means that we’re trying to fit a regression line that would minimize the square of distance from the regression line

# %%
predictions = model.predict(x)

# %%
predictions
# Out:
# 0       440426.085618
# 1       557866.735016
# 2       557396.972419
# 3       509950.950062
# 4       463914.215498
#             ...
# 8121    322985.436219
# 8122    509950.950062
# 8123    416468.193140
# 8124    555517.922029
# 8125    440426.085618
# Length: 6717, dtype: float64

# %%
print_model = model.summary()

# %%
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.196
# Method:                 Least Squares   F-statistic:                     1637.
# Date:                Fri, 29 Apr 2022   Prob (F-statistic):          1.43e-320
# Time:                        20:13:45   Log-Likelihood:                -97250.
# No. Observations:                6717   AIC:                         1.945e+05
# Df Residuals:                    6715   BIC:                         1.945e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.458e+05   1.76e+04     -8.299      0.000    -1.8e+05   -1.11e+05
# ...

# %% [markdown]
# MULTIPLE LINEAR REGRESSION

# %%
x = cars[['km_driven','mileage','engine','max_power']]
y = cars['selling_price']

# %%
model = sm.OLS(y, x).fit()

# %%
predictions = model.predict(x)

# %%
print_model = model.summary()

# %%
print(print_model)
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared (uncentered):                   0.746
# Model:                            OLS   Adj. R-squared (uncentered):              0.746
# Method:                 Least Squares   F-statistic:                              4927.
# Date:                Fri, 29 Apr 2022   Prob (F-statistic):                        0.00
# Time:                        20:13:10   Log-Likelihood:                         -95727.
# No. Observations:                6717   AIC:                                  1.915e+05
# Df Residuals:                    6713   BIC:                                  1.915e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# Bonus Automated EDA

# %%
pip install sweetviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sweetviz as sv

# %%
my_report = sv.analyze(cars)
my_report.show_html() # Default arguments will generate to "SWEETVIZ_REPORT.html"
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
