# %% [markdown]
# # if else ladder

# %%
marks=int(input("enter mark of the student"))
if marks>30 and marks<80:
    print ("The student has passed ")
elif  marks>80:
    print("The student has passed with distinction ")
else:
    print("student has failed")
# Out:
# enter mark of the student32
# The student has passed

# %% [markdown]
# # 5 different functions

# %%
def wish(name):
    print("Best of luck",name)
wish("Ravi")
def compute(daily_bill):
    electricity=int(input("Enter the daily electricity bill"))
    food=int(input("Enter  the daily food bill"))
    accomodation=int(input("Enter accomodtion rate"))
    daily_bill=electricity+food+accomodation
    print("the daily bill is",daily_bill)
compute("daily_bill")
def fullname(fname,lname):
    print("The full name is ",fname,lname)
print("Ravi","Tharakan")
def  calct(savings):
    salary=int((input("Enter the salary of Ravi")))
    expenditure=int((input("Enter the expenditure of Ravi")))
    savings=salary-expenditure
    print("Savings of Ravi Tharakan is",savings)
calct("savings")  
def share(charity) :
    ME=int((input("Monthly earning")))
    charity=10/100*ME
    print("charity ",charity)
share("charity")
# Out:
# Best of luck Ravi
# Enter the daily electricity bill20
# Enter  the daily food bill124
# Enter accomodtion rate290
# the daily bill is 434
# Ravi Tharakan
# Enter the salary of Ravi23000
# Enter the expenditure of Ravi12000
# Savings of Ravi Tharakan is 11000
# Monthly earning37000
# charity  3700.0

# %% [markdown]
# # Correlation matrix using given dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
df = pd.read_csv('C:/Users/Hp/Downloads/Tetuan City power consumption.csv')

# %%
df
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559      73.8       0.083
# 1         1/1/2017 0:10        6.414      74.5       0.083
# 2         1/1/2017 0:20        6.313      74.5       0.080
# 3         1/1/2017 0:30        6.121      75.0       0.083
# 4         1/1/2017 0:40        5.921      75.7       0.081
# ...                 ...          ...       ...         ...
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 1                      0.070          0.085               29814.68354
# ...

# %% [markdown]
# # missing value check

# %%
df.isnull().sum()
# Out:
# DateTime                     0
# Temperature                  0
# Humidity                     0
# Wind Speed                   0
# general diffuse flows        0
# diffuse flows                0
# Zone 1 Power Consumption     0
# Zone 2  Power Consumption    0
# Zone 3  Power Consumption    0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# it is clear that there is no null value in the given dataset

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure


df.hist(figsize=(12,8))
plt.show()

# %%
cor=df.corr()

# %%
cor
# Out:
#                            Temperature  Humidity  Wind Speed  \
# Temperature                   1.000000 -0.460243    0.477109
# Humidity                     -0.460243  1.000000   -0.135853
# Wind Speed                    0.477109 -0.135853    1.000000
# general diffuse flows         0.460294 -0.468138    0.133733
# diffuse flows                 0.196522 -0.256886   -0.000972
# Zone 1 Power Consumption      0.440221 -0.287421    0.167444
# Zone 2  Power Consumption     0.382428 -0.294961    0.146413
# Zone 3  Power Consumption     0.489527 -0.233022    0.278641
#
#                            general diffuse flows  diffuse flows  \
# Temperature                             0.460294       0.196522
# Humidity                               -0.468138      -0.256886
# Wind Speed                              0.133733      -0.000972
# general diffuse flows                   1.000000       0.564718
# diffuse flows                           0.564718       1.000000
# ...

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data=cor,annot=True,cmap='mako',center=0)
# Out:
# <AxesSubplot:>

# %% [markdown]
# we can draw conclusions from  the heatmap like there is very low correlation between diffuse flows and power consumptions in all the zones and the power consumptions  in different zones are  highly correlated between ecah other zones.

# %% [markdown]
# # slicing in dataset

# %%
df.columns
# Out:
# Index(['DateTime', 'Temperature', 'Humidity', 'Wind Speed',
#        'general diffuse flows', 'diffuse flows', 'Zone 1 Power Consumption',
#        'Zone 2  Power Consumption', 'Zone 3  Power Consumption'],
#       dtype='object')

# %%
df.head()
# Out:
#         DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0  1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1  1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2  1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3  1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4  1/1/2017 0:40        5.921      75.7       0.081                  0.048
#
#    diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 0          0.119               34055.69620                16128.87538
# 1          0.085               29814.68354                19375.07599
# 2          0.100               29128.10127                19006.68693
# 3          0.096               28228.86076                18361.09422
# 4          0.085               27335.69620                17872.34043
#
#    Zone 3  Power Consumption
# 0                20240.96386
# 1                20131.08434
# ...

# %%
df.shape
# Out:
# (52416, 9)

# %%
df.loc[52410:]
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 52410  12/30/2017 23:00        7.070      72.5       0.080
# 52411  12/30/2017 23:10        7.010      72.4       0.080
# 52412  12/30/2017 23:20        6.947      72.6       0.082
# 52413  12/30/2017 23:30        6.900      72.8       0.086
# 52414  12/30/2017 23:40        6.758      73.0       0.080
# 52415  12/30/2017 23:50        6.580      74.1       0.081
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 52410                  0.059          0.093               32158.17490
# 52411                  0.040          0.096               31160.45627
# 52412                  0.051          0.093               30430.41825
# 52413                  0.084          0.074               29590.87452
# 52414                  0.066          0.089               28958.17490
# 52415                  0.062          0.111               28349.80989
#
# ...

# %%
df.loc[52:62:3]
# Out:
#           DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 52   1/1/2017 8:40        4.346      74.8       0.082                  12.64
# 55   1/1/2017 9:10        4.624      74.1       0.082                 106.90
# 58   1/1/2017 9:40        4.524      74.7       0.081                 182.40
# 61  1/1/2017 10:10        5.836      71.3       2.660                 257.90
#
#     diffuse flows  Zone 1 Power Consumption  Zone 2  Power Consumption  \
# 52          10.13               20166.07595                12029.17933
# 55          22.55               22043.54430                13203.64742
# 58          28.19               23641.51899                14392.70517
# 61          31.01               25920.00000                15837.08207
#
#     Zone 3  Power Consumption
# 52                11514.21687
# 55                12427.95181
# 58                13648.19277
# 61                14428.91566

# %%
df.loc[::3]
# Out:
#                DateTime  Temperature  Humidity  Wind Speed  \
# 0         1/1/2017 0:00        6.559     73.80       0.083
# 3         1/1/2017 0:30        6.121     75.00       0.083
# 6         1/1/2017 1:00        5.641     77.70       0.080
# 9         1/1/2017 1:30        5.491     77.30       0.082
# 12        1/1/2017 2:00        5.059     78.60       0.081
# ...                 ...          ...       ...         ...
# 52401  12/30/2017 21:30        7.950     70.20       0.082
# 52404  12/30/2017 22:00        8.090     68.49       0.079
# 52407  12/30/2017 22:30        7.480     71.00       0.085
# 52410  12/30/2017 23:00        7.070     72.50       0.080
# 52413  12/30/2017 23:30        6.900     72.80       0.086
#
#        general diffuse flows  diffuse flows  Zone 1 Power Consumption  \
# 0                      0.051          0.119               34055.69620
# 3                      0.091          0.096               28228.86076
# ...

# %%
df.iloc[:19]
# Out:
#          DateTime  Temperature  Humidity  Wind Speed  general diffuse flows  \
# 0   1/1/2017 0:00        6.559      73.8       0.083                  0.051
# 1   1/1/2017 0:10        6.414      74.5       0.083                  0.070
# 2   1/1/2017 0:20        6.313      74.5       0.080                  0.062
# 3   1/1/2017 0:30        6.121      75.0       0.083                  0.091
# 4   1/1/2017 0:40        5.921      75.7       0.081                  0.048
# 5   1/1/2017 0:50        5.853      76.9       0.081                  0.059
# 6   1/1/2017 1:00        5.641      77.7       0.080                  0.048
# 7   1/1/2017 1:10        5.496      78.2       0.085                  0.055
# 8   1/1/2017 1:20        5.678      78.1       0.081                  0.066
# 9   1/1/2017 1:30        5.491      77.3       0.082                  0.062
# 10  1/1/2017 1:40        5.516      77.5       0.081                  0.051
# ...

# %%
df.iloc[1:10,2]
# Out:
# 1    74.5
# 2    74.5
# 3    75.0
# 4    75.7
# 5    76.9
# 6    77.7
# 7    78.2
# 8    78.1
# 9    77.3
# Name: Humidity, dtype: float64

# %%
df2=df[['Humidity','Temperature']]

# %%
df2
# Out:
#        Humidity  Temperature
# 0          73.8        6.559
# 1          74.5        6.414
# 2          74.5        6.313
# 3          75.0        6.121
# 4          75.7        5.921
# ...         ...          ...
# 52411      72.4        7.010
# 52412      72.6        6.947
# 52413      72.8        6.900
# 52414      73.0        6.758
# 52415      74.1        6.580
#
# [52416 rows x 2 columns]

# %%
df2.iloc[10:]
# Out:
#        Humidity  Temperature
# 10         77.5        5.516
# 11         76.7        5.471
# 12         78.6        5.059
# 13         78.8        4.968
# 14         78.9        4.975
# ...         ...          ...
# 52411      72.4        7.010
# 52412      72.6        6.947
# 52413      72.8        6.900
# 52414      73.0        6.758
# 52415      74.1        6.580
#
# [52406 rows x 2 columns]

# %% [markdown]
# # Can we find correlation between two categorical variables? How?

# %% [markdown]
# Yes .We can find correlation between two categorical variables.One statistical test that does this is the Chi Square Test of Independence, which is used to determine if there is an association between two or more categorical variables. if we assume that two variables are independent, then the values of the contingency table for these variables should be distributed uniformly. And then we check how far away from uniform the actual values are.We are not interested in testing the statistical significance however, we are more interested in effect size and specifically in the strength of association between the two variables.
