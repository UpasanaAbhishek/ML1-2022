# %% [markdown]
# # Assignment - 01
#
# # ML1 - LAB 01
#
# # 21BDA10 - Aishwarya C S

# %% [raw]
# Question - 1
#
# Program using if else statement.

# %%
vowel =  ['a','e','i','o','u']
cons = ['b','c','d','f','g','h','j','k','l','m','n','p','q','r','s','t','v','w','x','y','z']

# %%
str1 = str(input("Enter a letter : "))
if str1 in vowel:
    print("Given letter is a vowel")
elif str1 in cons:
    print("Given letter is consonants")
else:
    print("Entered letter is not a alphabet")
# Out:
# Enter a letter : o
# Given letter is a vowel

# %% [raw]
# Question - 2
#
# Program using 5 different functions

# %%
def rev(str2):
    res = str2[::-1]
    print(res)
def low(str2):
    res1 = str2.lower()
    print(res1)
def upp(str2):
    res2 = str2.upper()
    print(res2)
def concat(str2 , str3):
    res3 = str2 + str3
    print(res3)

str2 = str(input("Enter a word or sentence : "))
str3 = str(input("Enter a word or sentence : "))

print("\n1. Reverse method\n2. Lowercase method\n3. Upper case method\n4. Concatenation Method")
ch = int(input("Enter a choice : "))

if ch in [1,2,3,4]:
    if ch == 1:
        rev(str2)
    elif ch == 2:
        low(str2)
    elif ch == 3:
        upp(str2)
    elif ch == 4:
        concat(str2 , str3)
else:
    print("Invalid choice")
# Out:
# Enter a word or sentence : amma is best
# Enter a word or sentence :  and dad is best
#
# 1. Reverse method
# 2. Lowercase method
# 3. Upper case method
# 4. Concatenation Method
# Enter a choice : 4
# amma is best and dad is best

# %% [markdown]
# Question - 3
#
# using dataset

# %%
import pandas as pd

# %%
df1 = pd.read_csv("death-rates-from-air-pollution.csv")

# %%
df1
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
df1.head(10)
# Out:
#         Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0  Afghanistan  AFG  1990                                  299.477309
# 1  Afghanistan  AFG  1991                                  291.277967
# 2  Afghanistan  AFG  1992                                  278.963056
# 3  Afghanistan  AFG  1993                                  278.790815
# 4  Afghanistan  AFG  1994                                  287.162923
# 5  Afghanistan  AFG  1995                                  288.014224
# 6  Afghanistan  AFG  1996                                  286.642589
# 7  Afghanistan  AFG  1997                                  286.447455
# 8  Afghanistan  AFG  1998                                  286.265202
# 9  Afghanistan  AFG  1999                                  286.636018
#
#    Indoor air pollution (deaths per 100,000)  \
# 0                                 250.362910
# 1                                 242.575125
# 2                                 232.043878
# ...

# %%
df1.dtypes
# Out:
# Entity                                              object
# Code                                                object
# Year                                                 int64
# Air pollution (total) (deaths per 100,000)         float64
# Indoor air pollution (deaths per 100,000)          float64
# Outdoor particulate matter (deaths per 100,000)    float64
# Outdoor ozone pollution (deaths per 100,000)       float64
# dtype: object

# %%
df1.shape
# Out:
# (6468, 7)

# %%
df1.isna().sum()
# Out:
# Entity                                               0
# Code                                               980
# Year                                                 0
# Air pollution (total) (deaths per 100,000)           0
# Indoor air pollution (deaths per 100,000)            0
# Outdoor particulate matter (deaths per 100,000)      0
# Outdoor ozone pollution (deaths per 100,000)         0
# dtype: int64

# %% [markdown]
# From above it is clear that , only one column has null values.
# code column has 980 missing values.

# %%
df1.describe()
# Out:
#               Year  Air pollution (total) (deaths per 100,000)  \
# count  6468.000000                                 6468.000000
# mean   2003.500000                                   87.804083
# std       8.078372                                   57.845436
# min    1990.000000                                    8.401696
# 25%    1996.750000                                   41.016114
# 50%    2003.500000                                   72.653557
# 75%    2010.250000                                  127.607177
# max    2017.000000                                  318.463253
#
#        Indoor air pollution (deaths per 100,000)  \
# count                                6468.000000
# mean                                   50.481504
# std                                    58.722565
# min                                     0.003859
# 25%                                     2.002779
# 50%                                    23.737851
# ...

# %%
df1
# Out:
#            Entity Code  Year  Air pollution (total) (deaths per 100,000)  \
# 0     Afghanistan  AFG  1990                                  299.477309
# 1     Afghanistan  AFG  1991                                  291.277967
# 2     Afghanistan  AFG  1992                                  278.963056
# 3     Afghanistan  AFG  1993                                  278.790815
# 4     Afghanistan  AFG  1994                                  287.162923
# ...           ...  ...   ...                                         ...
# 6463     Zimbabwe  ZWE  2013                                  143.850145
# 6464     Zimbabwe  ZWE  2014                                  138.200536
# 6465     Zimbabwe  ZWE  2015                                  132.752553
# 6466     Zimbabwe  ZWE  2016                                  128.692138
# 6467     Zimbabwe  ZWE  2017                                  125.028843
#
#       Indoor air pollution (deaths per 100,000)  \
# ...

# %%
import matplotlib.pyplot as plt
df1.hist(figsize = (10,14) , column = ["Air pollution (total) (deaths per 100,000)", "Indoor air pollution (deaths per 100,000)",
                                      "Outdoor particulate matter (deaths per 100,000)","Outdoor ozone pollution (deaths per 100,000)"])
plt.show()

# %%
# CORRELATION MATRIX
df1.corr()
# Out:
#                                                      Year  \
# Year                                             1.000000
# Air pollution (total) (deaths per 100,000)      -0.225142
# Indoor air pollution (deaths per 100,000)       -0.185118
# Outdoor particulate matter (deaths per 100,000) -0.106214
# Outdoor ozone pollution (deaths per 100,000)    -0.097299
#
#                                                  Air pollution (total) (deaths per 100,000)  \
# Year                                                                              -0.225142
# Air pollution (total) (deaths per 100,000)                                         1.000000
# Indoor air pollution (deaths per 100,000)                                          0.946052
# Outdoor particulate matter (deaths per 100,000)                                    0.090381
# Outdoor ozone pollution (deaths per 100,000)                                       0.343790
#
# ...

# %%
import seaborn as sns
plt.figure(figsize=(8,8))
ax = sns.heatmap(df1.corr() , annot = True)

# %% [markdown]
# Death due to Total Air Pollution and Death due to Indoor air pollution are  positively correlated. correlation between two variable is 0.95
#
# Death due to outdoor particulate matter and Death due to Indoor air pollution are negatively correlated. correlarion betwen these two variables are -0.23

# %% [markdown]
# Question - 4

# %%
df2 = pd.read_csv("bestsellers_with_categories_2022_03_27.csv")

# %%
df2
# Out:
#                                                   Name                 Author  \
# 0    Act Like a Lady, Think Like a Man: What Men Re...           Steve Harvey
# 1    Arguing with Idiots: How to Stop Small Minds a...             Glenn Beck
# 2            Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 3          Crazy Love: Overwhelmed by a Relentless God           Francis Chan
# 4    Dead And Gone: A Sookie Stackhouse Novel (Sook...       Charlaine Harris
# ..                                                 ...                    ...
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
# 696                                 Ugly Love: A Novel         Colleen Hoover
# 697                                             Verity         Colleen Hoover
# 698               What to Expect When You're Expecting          Heidi Murkoff
# 699                            Where the Crawdads Sing            Delia Owens
#
# ...

# %%
df2.head()
# Out:
#                                                 Name            Author  \
# 0  Act Like a Lady, Think Like a Man: What Men Re...      Steve Harvey
# 1  Arguing with Idiots: How to Stop Small Minds a...        Glenn Beck
# 2          Breaking Dawn (The Twilight Saga, Book 4)   Stephenie Meyer
# 3        Crazy Love: Overwhelmed by a Relentless God      Francis Chan
# 4  Dead And Gone: A Sookie Stackhouse Novel (Sook...  Charlaine Harris
#
#    User Rating  Reviews  Price  Year        Genre
# 0          4.6     5013     17  2009  Non Fiction
# 1          4.6      798      5  2009  Non Fiction
# 2          4.6     9769     13  2009      Fiction
# 3          4.7     1542     14  2009  Non Fiction
# 4          4.6     1541      4  2009      Fiction

# %%
df2[0:16]
# Out:
#                                                  Name            Author  \
# 0   Act Like a Lady, Think Like a Man: What Men Re...      Steve Harvey
# 1   Arguing with Idiots: How to Stop Small Minds a...        Glenn Beck
# 2           Breaking Dawn (The Twilight Saga, Book 4)   Stephenie Meyer
# 3         Crazy Love: Overwhelmed by a Relentless God      Francis Chan
# 4   Dead And Gone: A Sookie Stackhouse Novel (Sook...  Charlaine Harris
# 5       Diary of a Wimpy Kid: The Last Straw (Book 3)       Jeff Kinney
# 6   Divine Soul Mind Body Healing and Transmission...      Zhi Gang Sha
# 7   Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...       Jeff Kinney
# 8   Eat This Not That! Supermarket Survival Guide:...   David Zinczenko
# 9   Eat This, Not That! Thousands of Simple Food S...   David Zinczenko
# 10                           Eclipse (Twilight Sagas)   Stephenie Meyer
# 11                                 Eclipse (Twilight)   Stephenie Meyer
# ...

# %%
df2[-5::]
# Out:
#                                      Name                 Author  User Rating  \
# 695      The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 696                    Ugly Love: A Novel         Colleen Hoover          4.7
# 697                                Verity         Colleen Hoover          4.6
# 698  What to Expect When You're Expecting          Heidi Murkoff          4.8
# 699               Where the Crawdads Sing            Delia Owens          4.8
#
#      Reviews  Price  Year        Genre
# 695    20920      9  2022      Fiction
# 696    33929     10  2022      Fiction
# 697    71826     11  2022      Fiction
# 698    27052     13  2022  Non Fiction
# 699   208917     10  2022      Fiction

# %%
df2[-15::]
# Out:
#                                                   Name                 Author  \
# 685                 The Last Thing He Told Me: A Novel             Laura Dave
# 686                       The Lincoln Highway: A Novel            Amor Towles
# 687                                The Love Hypothesis          Ali Hazelwood
# 688                                  The Maid: A Novel             Nita Prose
# 689                      The Midnight Library: A Novel              Matt Haig
# 690  The Real Anthony Fauci: Bill Gates, Big Pharma...  Robert F. Kennedy Jr.
# 691         The Seven Husbands of Evelyn Hugo: A Novel    Taylor Jenkins Reid
# 692  The Subtle Art of Not Giving a F*ck: A Counter...            Mark Manson
# 693                        The Very Hungry Caterpillar             Eric Carle
# 694  The Whole Body Reset: Your Weight-Loss Plan fo...        Stephen Perrine
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
# ...

# %%
df2.iloc[12:30]
# Out:
#                                                  Name  \
# 12  Glenn Beck's Common Sense: The Case Against an...
# 13                      Going Rogue: An American Life
# 14  Good to Great: Why Some Companies Make the Lea...
# 15                  Have a Little Faith: A True Story
# 16                                      I, Alex Cross
# 17      Liberty and Tyranny: A Conservative Manifesto
# 18        Mastering the Art of French Cooking, Vol. 2
# 19                       New Moon (The Twilight Saga)
# 20                                   Olive Kitteridge
# 21                     Outliers: The Story of Success
# 22  Publication Manual of the American Psychologic...
# 23                                  Sookie Stackhouse
# 24                                StrengthsFinder 2.0
# 25  Super Freakonomics: Global Cooling, Patriotic ...
# 26                                 The 5000 Year Leap
# 27  The 7 Habits of Highly Effective People: Power...
# ...

# %%
df2.iloc[[5,12],[1,4]]
# Out:
#          Author  Price
# 5   Jeff Kinney     15
# 12   Glenn Beck     11

# %% [markdown]
# Question - 5
#
# Can we find correlation between 2 categorical variables? How?
#
# Yes , we can find the correlation between two categorical variables by using Spearman Rank Correlation method.
