# %% [markdown]
# <center><h1> ASSIGNMENT-2</h1></center>
# <center><h1>Laptop_price</h1></center>
#
# ### HITESH S
# ### 21BDA47

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
sns.set(style="darkgrid")

# %%
LAPPRICE = pd.read_csv("Downloads\laptop_price.csv")
LAPPRICE
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
LAPPRICE.head(10)
# Out:
#    laptop_ID Company          Product   TypeName  Inches  \
# 0          1   Apple      MacBook Pro  Ultrabook    13.3
# 1          2   Apple      Macbook Air  Ultrabook    13.3
# 2          3      HP           250 G6   Notebook    15.6
# 3          4   Apple      MacBook Pro  Ultrabook    15.4
# 4          5   Apple      MacBook Pro  Ultrabook    13.3
# 5          6    Acer         Aspire 3   Notebook    15.6
# 6          7   Apple      MacBook Pro  Ultrabook    15.4
# 7          8   Apple      Macbook Air  Ultrabook    13.3
# 8          9    Asus  ZenBook UX430UN  Ultrabook    14.0
# 9         10    Acer          Swift 3  Ultrabook    14.0
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# ...

# %%
LAPPRICE['Inches'].value_counts()
# Out:
# 15.6    665
# 14.0    197
# 13.3    164
# 17.3    164
# 12.5     39
# 11.6     33
# 13.5      6
# 13.9      6
# 12.0      6
# 12.3      5
# 10.1      4
# 15.0      4
# 15.4      4
# 13.0      2
# 11.3      1
# 14.1      1
# 17.0      1
# 18.4      1
# Name: Inches, dtype: int64

# %%
LAPPRICE['Weight'].value_counts()
# Out:
# 2.2kg     121
# 2.1kg      58
# 2.4kg      44
# 2.3kg      41
# 2.5kg      38
#          ...
# 3.74kg      1
# 4.7kg       1
# 2.79kg      1
# 1.55kg      1
# 2.21kg      1
# Name: Weight, Length: 179, dtype: int64

# %%
LAPPRICE['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz     190
# Intel Core i7 7700HQ 2.8GHz    146
# Intel Core i7 7500U 2.7GHz     134
# Intel Core i7 8550U 1.8GHz      73
# Intel Core i5 8250U 1.6GHz      72
#                               ...
# AMD A9-Series 9420 2.9GHz        1
# Intel Core i7 7700HQ 2.7GHz      1
# Intel Atom Z8350 1.92GHz         1
# AMD E-Series E2-6110 1.5GHz      1
# Intel Core i5 7200U 2.7GHz       1
# Name: Cpu, Length: 118, dtype: int64

# %%
LAPPRICE.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
LAPPRICE.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
LAPPRICE.corr()
# Out:
#              laptop_ID    Inches  Price_euros
# laptop_ID     1.000000 -0.087796     0.067830
# Inches       -0.087796  1.000000     0.068197
# Price_euros   0.067830  0.068197     1.000000

# %%
LAPPRICE.isnull().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
LAPPRICE.groupby('Ram')['Price_euros'].mean()
# Out:
# Ram
# 12GB    1239.438400
# 16GB    1936.771150
# 24GB    2206.333333
# 2GB      254.370455
# 32GB    3413.085882
# 4GB      574.572480
# 64GB    3975.000000
# 6GB      615.206341
# 8GB     1180.812940
# Name: Price_euros, dtype: float64

# %%
LAPPRICE.groupby('Inches')['Price_euros'].mean()
# Out:
# Inches
# 10.1     498.317500
# 11.3    1299.000000
# 11.6     393.613636
# 12.0    1279.900000
# 12.3    1228.200000
# 12.5    1583.493077
# 13.0    1424.000000
# 13.3    1332.318354
# 13.5    1612.308333
# 13.9    1637.333333
# 14.0    1202.269239
# 14.1     348.000000
# 15.0    1464.000000
# 15.4    2493.847500
# 15.6     903.355699
# 17.0     520.900000
# 17.3    1673.061402
# 18.4    2799.000000
# Name: Price_euros, dtype: float64

# %% [markdown]
# ### Visualize the Data
#
# ### Relational Plots

# %%
sns.relplot(x = "Inches", y = "ScreenResolution", height = 10, data = LAPPRICE)

# %%
sns.relplot(x = "Inches", y = "Company", data = LAPPRICE)

# %%
sns.relplot(x = "Ram", y = "Company", data = LAPPRICE)

# %%
sns.relplot(x = "Ram", y = "Company",hue = "TypeName", data = LAPPRICE)

# %%
sns.relplot(x = "Ram", y = "Company",hue = "TypeName", data = LAPPRICE, palette = ['darkblue','green','orange','yellow','red','black'])

# %%
sns.relplot(x = "Ram",y = "Company",hue = "TypeName", style = "OpSys",height = 6,data = LAPPRICE);

# %%
sns.relplot(x = "Ram",y = "Company",hue = "Inches",size = "Inches",sizes = (10,200),data = LAPPRICE)

# %% [markdown]
# ### Scatter Plots

# %%
sns.scatterplot(x = "Ram", y = "Company", hue= "Inches", data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Company'>

# %%
sns.scatterplot(x = "Ram", y = "Company", hue= "Inches",style= "TypeName", data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Company'>

# %% [markdown]
# ### Categorical Plots

# %%
sns.catplot(x = "TypeName", y= "Price_euros", height = 8, data = LAPPRICE);

# %%
sns.catplot(x = "Ram", y = "TypeName", height = 8, data = LAPPRICE)

# %%
sns.catplot(x = "Ram", y = "Inches", height = 8, data = LAPPRICE);

# %%
sns.catplot(x = "Inches", y = "TypeName",hue= "Company", height = 8, data = LAPPRICE)

# %%
sns.catplot(x = "Inches", y = "TypeName",hue= "Company",jitter =True,alpha = 0.2,height = 8,data= LAPPRICE)

# %%
sns.catplot(x = "Inches", y = "TypeName",hue= "Company",jitter =False,alpha = 0.2,height = 8,data= LAPPRICE)

# %% [markdown]
# ### Bee Swarm Plot

# %%
sns.swarmplot(x = "Inches", y = "TypeName", hue = "Ram", size = 5 ,data = LAPPRICE)
# Out:
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 78.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 96.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 60.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.stripplot(x = "Ram", y = "OpSys",size = 5,data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='OpSys'>

# %%
sns.stripplot(x = "Ram", y = "OpSys",hue= "TypeName",size = 5,data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='OpSys'>

# %% [markdown]
# ### Box Plots

# %%
sns.boxplot(x = "Inches", y = "TypeName", data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='TypeName'>

# %%
sns.boxplot(x = "Inches", y = "OpSys",data= LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='OpSys'>

# %%
sns.boxplot(x = "Price_euros", y = "OpSys",data= LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='OpSys'>

# %% [markdown]
# ### Boxen Plot

# %%
sns.boxenplot(x = "Price_euros", y = "Company", data= LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='Company'>

# %%
sns.boxenplot(x = "Price_euros", y = "TypeName",data= LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='TypeName'>

# %%
sns.boxenplot(x = "Inches", y = "OpSys",data= LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Inches', ylabel='OpSys'>

# %% [markdown]
# ### Fancy Box Plot

# %%
sns.violinplot(y ="OpSys", x = "Price_euros", bw = 55,split = True,palette= "pastel", inner= "box", width = 1, data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='OpSys'>

# %%
sns.violinplot(x ="TypeName", y = "Inches",bw = 10,split = True,palette= "pastel", inner= "quartile", width = 1, data= LAPPRICE)
# Out:
# <AxesSubplot:xlabel='TypeName', ylabel='Inches'>

# %%
sns.violinplot(x ="Ram", y = "Price_euros", inner = None, width = 4, data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price_euros'>

# %% [markdown]
# Overlap two kind of plots

# %%
sns.violinplot(x = "TypeName", y = "Price_euros", inner = None, data = LAPPRICE)
sns.swarmplot(x = "TypeName", y = "Price_euros", color = "k", size = 10, data = LAPPRICE)
# Out:
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 84.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 94.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 48.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 80.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.violinplot(x = "Ram", y = "Inches", inner = None, data = LAPPRICE)
sns.swarmplot(x = "Ram", y = "Inches", color = "k", size = 10, data = LAPPRICE)
# Out:
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 96.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 92.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 94.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hites\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 59.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ### BAR PLOT

# %%
sns.barplot(y = "TypeName", x= "Price_euros", data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='TypeName'>

# %%
A=sns.barplot(x = "Ram", y= "Price_euros", data = LAPPRICE)

# %% [markdown]
# ### Bars by categories

# %%
sns.countplot(y = "TypeName", data = LAPPRICE);

# %%
ax = sns.countplot(x="Ram", data=LAPPRICE,
                   facecolor=(0, 0, 0, 0),
                   linewidth=5,
                   edgecolor=sns.color_palette("dark", 3))

# %% [markdown]
# ### Point plots

# %%
sns.pointplot(x = "Ram", y= "Price_euros", data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price_euros'>

# %%
sns.pointplot(y = "TypeName", x= "Price_euros", data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='TypeName'>

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data=LAPPRICE, x="Price_euros",kde = True)
# Out:
# <AxesSubplot:xlabel='Price_euros', ylabel='Count'>

# %%
sns.lineplot(x = "Ram",y ="Price_euros",data = LAPPRICE)
# Out:
# <AxesSubplot:xlabel='Ram', ylabel='Price_euros'>

# %% [markdown]
# ### Simple Linear Regression Model

# %%
LAPPRICE.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
Sepc = LAPPRICE[['Ram','Price_euros']]
Sepc
# Out:
#        Ram  Price_euros
# 0      8GB      1339.69
# 1      8GB       898.94
# 2      8GB       575.00
# 3     16GB      2537.45
# 4      8GB      1803.60
# ...    ...          ...
# 1298   4GB       638.00
# 1299  16GB      1499.00
# 1300   2GB       229.00
# 1301   6GB       764.00
# 1302   4GB       369.00
#
# [1303 rows x 2 columns]

# %%
Sepc.corr()
# Out:
#              Price_euros
# Price_euros          1.0

# %% [markdown]
# ### Multiple Linear Regression Model

# %%
LAPPRICE.columns
# Out:
# Index(['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_euros'],
#       dtype='object')

# %%
x = LAPPRICE.loc[:,["Inches"]].values

y = LAPPRICE.loc[:,"Price_euros"].values.reshape(-1,1)

# %%
Sepc1 = LAPPRICE[["Inches"]]
Sepc1
# Out:
#       Inches
# 0       13.3
# 1       13.3
# 2       15.6
# 3       15.4
# 4       13.3
# ...      ...
# 1298    14.0
# 1299    13.3
# 1300    14.0
# 1301    15.6
# 1302    15.6
#
# [1303 rows x 1 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=4)

# %%
S = LinearRegression()
S.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("beta_0 =",S.intercept_)
print("slopes  = ",S.coef_.round(2),"\n")
# Out:
# beta_0 = [639.42286174]
# slopes  =  [[31.67]]

# %%
print("R =",(S.score(X_train, y_train)))
# Out:
# R = 0.00426834338507287

# %%
0.00426834338507287*100
# Out:
# 0.426834338507287

# %%
100-0.426834338507287
# Out:
# 99.57316566149271

# %%
Spec_pred = S.predict(X_test)
Spec_pred
# Out:
# array([[1133.42889926],
#        [1133.42889926],
#        [1133.42889926],
#        [1133.42889926],
#        [1133.42889926],
#        [1133.42889926],
#        [1114.42866704],
#        [1035.26103283],
#        [1133.42889926],
#        [1133.42889926],
#        [1060.59467578],
#        [1082.76161336],
#        [1187.26289052],
#        [1187.26289052],
#        [1006.76068451],
#        [1133.42889926],
#        [1133.42889926],
#        [1006.76068451],
#        [1133.42889926],
#        [1133.42889926],
#        [1006.76068451],
#        [1082.76161336],
#        [1187.26289052],
#        [1133.42889926],
#        [1082.76161336],
#        [1082.76161336],
#        [1082.76161336],
#        [1133.42889926],
#        [1082.76161336],
#        [1133.42889926],
#        [1133.42889926],
#        [1060.59467578],
#        [1082.76161336],
#        [1082.76161336],
#        [1133.42889926],
#        [1133.42889926],
#        [1133.42889926],
#        [1060.59467578],
# ...

# %%
x = LAPPRICE.drop(columns=['Price_euros'], axis=5)
plt.figure(figsize=(14, 10))
sns.heatmap(x.corr(), center=0)
plt.show()
