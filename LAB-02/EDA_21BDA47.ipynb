# %% [markdown]
# <center><h1> ASSIGNMENT-2</h1></center>
# <center><h1>EDA</h1></center>
#
# ### HITESH S
# ### 21BDA47

# %%
import numpy as np
import pandas as pd
import sweetviz 
import dtale
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="darkgrid")

# %%
LAPPRICE = pd.read_csv("Downloads\laptop_price.csv")
LAPPRICE
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
LAPPRICE.isna().sum()
# Out:
# laptop_ID           0
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
report = sweetviz.analyze(LAPPRICE)
report
# Out:
#                                              |                                             | [  0%]   00:00 ->…

# %%
report.show_html()
# Out:
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
d = dtale.show(LAPPRICE)
d.open_browser()
# Out:
# Exception on /dtale/main/Roboto-Regular.ttf [GET]
# Traceback (most recent call last):
#   File "C:\Users\hites\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\hites\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\hites\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\Users\hites\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\Users\hites\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\hites\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
# ...

# %%
pandas_profiling.ProfileReport(LAPPRICE)
# Out:
# 2022-04-29 18:56:30,145 - INFO     - Pandas backend loaded 1.2.4
# 2022-04-29 18:56:30,180 - INFO     - Numpy backend loaded 1.20.1
# 2022-04-29 18:56:30,180 - INFO     - Pyspark backend NOT loaded
# 2022-04-29 18:56:30,187 - INFO     - Python backend loaded
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# ...
