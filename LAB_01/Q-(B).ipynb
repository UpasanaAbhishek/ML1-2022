# %% [markdown]
# #### QUESTION 1

# %% [markdown]
# #### Write a program that uses an if-else ladder

# %%
num = 7
if num == 1:
    print("one")
elif num == 2:
    print("two")    
else:
    print("more than two")
# Out:
# more than two

# %% [markdown]
# #### QUESTION 2

# %% [markdown]
# #### Write 5 different functions and call them in one program.

# %%
import math as math

def add(a,b):
    return (a+b)
def diff(a,b):
    return(a-b)
def multi(a,b):
    return(a*b)
def div(a,b):
    return(a/b)
print("The sum of two numbers: ",add(11,22))
print("The difference of two numbers: ",diff(11,22))
print("The product of two numbers: ",multi(11,22))
print("The quotient of two numbers: ",div(11,22))
# Out:
# The sum of two numbers:  33
# The difference of two numbers:  -11
# The product of two numbers:  242
# The quotient of two numbers:  0.5

# %% [markdown]
# #### QUESTION 3

# %% [markdown]
# #### Read any dataset from https://archive.ics.uci.edu/ml/index.php and perform a missing value treatment, check for distribution of each variable, find the correlation matrix and write conclusions from the matrix

# %%
import pandas as pd

# %%
df = pd.read_csv("Usedcars.csv")
df.head(10)
# Out:
#         Make          Type  Year Origin   Color    Options  Engine_Size  \
# 0   Chrysler          C300  2018  Saudi   Black       Full          5.7
# 1     Nissan        Patrol  2016  Saudi   White       Full          4.8
# 2     Nissan         Sunny  2019  Saudi  Silver   Standard          1.5
# 3    Hyundai       Elantra  2019  Saudi    Grey   Standard          1.6
# 4    Hyundai       Elantra  2019  Saudi  Silver  Semi Full          2.0
# 5      Honda        Accord  2018  Saudi    Navy       Full          1.5
# 6     Toyota  Land Cruiser  2011  Saudi   White  Semi Full          4.5
# 7        GMC         Yukon  2009  Saudi  Bronze       Full          5.7
# 8  Chevrolet        Impala  2019  Saudi   Black   Standard          3.6
# 9     Toyota         Yaris  2018  Saudi   White   Standard          1.5
#
#   Fuel_Type  Gear_Type  Mileage  Region   Price  Negotiable
# 0       Gas  Automatic   103000  Riyadh  114000       False
# ...

# %%
df.shape
# Out:
# (8035, 13)

# %%
df.Year.value_counts()
# Out:
# 2016    1191
# 2015     814
# 2017     809
# 2018     761
# 2019     632
# 2014     566
# 2020     552
# 2013     502
# 2012     314
# 2011     258
# 2010     211
# 2008     193
# 2021     190
# 2009     173
# 2007     164
# 2006     139
# 2005      82
# 2004      65
# 2003      60
# 2002      54
# 1999      43
# 2001      37
# 1997      28
# 1998      26
# 2000      25
# 1995      22
# 1993      15
# 1990      12
# 1994      12
# 1996      10
# 1991      10
# 1983       8
# 1992       7
# 1989       7
# 1982       6
# 1986       4
# 1988       4
# 1980       3
# 1978       3
# 1981       3
# 1987       3
# 1984       3
# 1985       3
# 1979       2
# 2022       2
# 1964       1
# 1963       1
# 1965       1
# 1972       1
# 1970       1
# 1975       1
# 1977       1
# Name: Year, dtype: int64

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of            Make          Type  Year       Origin   Color    Options  \
# 0      Chrysler          C300  2018        Saudi   Black       Full
# 1        Nissan        Patrol  2016        Saudi   White       Full
# 2        Nissan         Sunny  2019        Saudi  Silver   Standard
# 3       Hyundai       Elantra  2019        Saudi    Grey   Standard
# 4       Hyundai       Elantra  2019        Saudi  Silver  Semi Full
# ...         ...           ...   ...          ...     ...        ...
# 8030       Audi            A6  2015        Saudi  Silver       Full
# 8031  Chevrolet        Camaro  2010        Saudi  Silver       Full
# 8032     Toyota  Land Cruiser  2013  Gulf Arabic   White       Full
# 8033     Nissan        Altima  2011        Saudi  Silver       Full
# 8034   Cadillac         Other  2013        Saudi   White       Full
#
#       Engine_Size Fuel_Type  Gear_Type  Mileage     Region   Price  Negotiable
# ...

# %%
df.describe()
# Out:
#               Year  Engine_Size       Mileage         Price
# count  8035.000000  8035.000000  8.035000e+03  8.035000e+03
# mean   2014.097698     3.287729  1.491488e+05  5.369984e+04
# std       5.757228     1.517747  3.474480e+05  7.198472e+04
# min    1963.000000     1.000000  1.000000e+02  0.000000e+00
# 25%    2012.000000     2.000000  3.700000e+04  0.000000e+00
# 50%    2016.000000     3.000000  1.019600e+05  3.700000e+04
# 75%    2018.000000     4.400000  1.950000e+05  7.375000e+04
# max    2022.000000     9.000000  2.000000e+07  1.150000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8035 entries, 0 to 8034
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         8035 non-null   object
#  1   Type         8035 non-null   object
#  2   Year         8035 non-null   int64
#  3   Origin       8035 non-null   object
#  4   Color        8035 non-null   object
#  5   Options      8035 non-null   object
#  6   Engine_Size  8035 non-null   float64
#  7   Fuel_Type    8035 non-null   object
#  8   Gear_Type    8035 non-null   object
#  9   Mileage      8035 non-null   int64
#  10  Region       8035 non-null   object
#  11  Price        8035 non-null   int64
#  12  Negotiable   8035 non-null   bool
# dtypes: bool(1), float64(1), int64(3), object(8)
# memory usage: 761.3+ KB

# %% [markdown]
# ## Data cleaning

# %%
#data cleaning

df.isnull().sum()
# Out:
# Make           0
# Type           0
# Year           0
# Origin         0
# Color          0
# Options        0
# Engine_Size    0
# Fuel_Type      0
# Gear_Type      0
# Mileage        0
# Region         0
# Price          0
# Negotiable     0
# dtype: int64

# %%
#drop duplicate rows

df.drop_duplicates(inplace=True)
print("Number of duplicate rows: ",sum(df.duplicated()))
# Out:
# Number of duplicate rows:  0

# %% [markdown]
# ### Dropping irrelevant columns

# %%
#'negotiable' column is not necessary so we can drop that.

data = df.drop(['Negotiable'], axis=1)
data.head()
# Out:
#        Make     Type  Year Origin   Color    Options  Engine_Size Fuel_Type  \
# 0  Chrysler     C300  2018  Saudi   Black       Full          5.7       Gas
# 1    Nissan   Patrol  2016  Saudi   White       Full          4.8       Gas
# 2    Nissan    Sunny  2019  Saudi  Silver   Standard          1.5       Gas
# 3   Hyundai  Elantra  2019  Saudi    Grey   Standard          1.6       Gas
# 4   Hyundai  Elantra  2019  Saudi  Silver  Semi Full          2.0       Gas
#
#    Gear_Type  Mileage  Region   Price
# 0  Automatic   103000  Riyadh  114000
# 1  Automatic     5448  Riyadh       0
# 2  Automatic    72418  Riyadh   27500
# 3  Automatic   114154  Riyadh   43000
# 4  Automatic    41912  Riyadh   59500

# %%
data.describe(exclude="number")
# Out:
#           Make          Type Origin  Color Options Fuel_Type  Gear_Type  \
# count     8032          8032   8032   8032    8032      8032       8032
# unique      59           381      4     15       3         3          2
# top     Toyota  Land Cruiser  Saudi  White    Full       Gas  Automatic
# freq      2037           372   5961   3477    3191      7858       6968
#
#         Region
# count     8032
# unique      27
# top     Riyadh
# freq      3236

# %% [markdown]
# ##### We could find that Toyota Land Cruiser is the most selling car also White is the most preferable color. For car sales, Riyadh is the most popular city.

# %%
#to check rows with price = 0

data[data.Price == 0]
# Out:
#         Make          Type  Year       Origin   Color    Options  Engine_Size  \
# 1     Nissan        Patrol  2016        Saudi   White       Full          4.8
# 7        GMC         Yukon  2009        Saudi  Bronze       Full          5.7
# 18       GMC         Yukon  2018        Saudi   White       Full          5.3
# 26    Toyota         Camry  2019        Saudi     Red       Full          2.5
# 28    Toyota        Avalon  2008        Other     Red       Full          3.5
# ...      ...           ...   ...          ...     ...        ...          ...
# 8018   Mazda           CX9  2015        Saudi     Red   Standard          3.6
# 8021    Ford      Explorer  2010        Other   Black  Semi Full          1.6
# 8022  Toyota     Furniture  2020        Saudi   White  Semi Full          2.7
# 8024  Toyota     Furniture  2014        Saudi   White  Semi Full          4.0
# 8032  Toyota  Land Cruiser  2013  Gulf Arabic   White       Full          4.6
#
# ...

# %%
#dropping price columns with zero values

data = data[data['Price'] != 0]
data.head(10)
# Out:
#          Make          Type  Year       Origin   Color    Options  \
# 0    Chrysler          C300  2018        Saudi   Black       Full
# 2      Nissan         Sunny  2019        Saudi  Silver   Standard
# 3     Hyundai       Elantra  2019        Saudi    Grey   Standard
# 4     Hyundai       Elantra  2019        Saudi  Silver  Semi Full
# 5       Honda        Accord  2018        Saudi    Navy       Full
# 6      Toyota  Land Cruiser  2011        Saudi   White  Semi Full
# 8   Chevrolet        Impala  2019        Saudi   Black   Standard
# 9      Toyota         Yaris  2018        Saudi   White   Standard
# 10     Toyota         Camry  2017  Gulf Arabic   White   Standard
# 11     Nissan        Patrol  2014        Saudi   White       Full
#
#     Engine_Size Fuel_Type  Gear_Type  Mileage  Region   Price
# 0           5.7       Gas  Automatic   103000  Riyadh  114000
# 2           1.5       Gas  Automatic    72418  Riyadh   27500
# ...

# %% [markdown]
# ## Data visualization

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %%
figure(figsize=(10,8))
data.hist()
plt.show()

# %%
print("\t\t\t\t CORRELATION MATRIX \t\t\t\t")

r = data.corr()
r
# Out:
# 				 CORRELATION MATRIX
#                  Year  Engine_Size   Mileage     Price
# Year         1.000000    -0.227199 -0.185859  0.307989
# Engine_Size -0.227199     1.000000  0.041266  0.303810
# Mileage     -0.185859     0.041266  1.000000 -0.118980
# Price        0.307989     0.303810 -0.118980  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18,8))
sns.heatmap(data.corr(),annot=True)
plt.title("Correlation", size = 15)
plt.show()

# %%
#another way to calculate the correlation

data.corr()["Price"].sort_values()
# Out:
# Mileage       -0.118980
# Engine_Size    0.303810
# Year           0.307989
# Price          1.000000
# Name: Price, dtype: float64

# %% [markdown]
# ##### The dataset is from https://archive.ics.uci.edu/ml/index.php
#
# #### INSIGHTS
#
# ##### 1. The dataset is about the historical records of used cars from the year 1960 upto 2021.
# ##### 2. Data set only talks about Saudi Arabian states.
# ##### 3. It contains the company details, manufacturing year, location where the car was sold, different colour types and fuel types, average mileage in different cities, their transmission type also price values.
# ##### 4. Toyota Land Cruiser is the most selling car.
# ##### 5. White is most preferable color.
# ##### 6. Based on the car deatils, major business comes from Riyadh.
# ##### 7. From the heatmap, we can see the Option, Year, and Engine_Size are positively correlated variables to price. Whereas Mileage is negatively correlated.

# %% [markdown]
# #### QUESTION 4

# %% [markdown]
# #### Read a dataset and perform slice it in different ways

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Deepak K/Downloads/accelerometer.csv")

# %%
df
# Out:
#         wconfid  pctid      x      y      z
# 0             1     20  1.004  0.090 -0.125
# 1             1     20  1.004 -0.043 -0.125
# 2             1     20  0.969  0.090 -0.121
# 3             1     20  0.973 -0.012 -0.137
# 4             1     20  1.000 -0.016 -0.121
# ...         ...    ...    ...    ...    ...
# 152995        3    100  1.051  0.090 -0.262
# 152996        3    100  0.918  0.039 -0.129
# 152997        3    100  1.156 -0.094 -0.227
# 152998        3    100  0.934  0.203 -0.172
# 152999        3    100  1.199 -0.176  0.109
#
# [153000 rows x 5 columns]

# %%
df.iloc[2:9]
# Out:
#    wconfid  pctid      x      y      z
# 2        1     20  0.969  0.090 -0.121
# 3        1     20  0.973 -0.012 -0.137
# 4        1     20  1.000 -0.016 -0.121
# 5        1     20  0.961  0.082 -0.121
# 6        1     20  0.973 -0.055 -0.109
# 7        1     20  1.000  0.012 -0.133
# 8        1     20  0.969 -0.102 -0.141

# %%
df.iloc[[1,5]]
# Out:
#    wconfid  pctid      x      y      z
# 1        1     20  1.004 -0.043 -0.125
# 5        1     20  0.961  0.082 -0.121

# %%
df.loc[:,"pctid"]
# Out:
# 0          20
# 1          20
# 2          20
# 3          20
# 4          20
#          ...
# 152995    100
# 152996    100
# 152997    100
# 152998    100
# 152999    100
# Name: pctid, Length: 153000, dtype: int64

# %%
df1[:2]
# Out:
#    wconfid  pctid      x      y      z
# 0        1     20  1.004  0.090 -0.125
# 1        1     20  1.004 -0.043 -0.125

# %%
df[1:2]
# Out:
#    wconfid  pctid      x      y      z
# 1        1     20  1.004 -0.043 -0.125

# %% [markdown]
# #### QUESTION 5

# %% [markdown]
# #### Can we find correlation between two categorical variables? How?

# %% [markdown]
# we use the Pearson Correlation Coefficient to calculate the correlation between continuous numerical variables.
# for categorical variables like-
# Marital status (single, married, divorced)
# Smoking status (smoker, non-smoker)
# Eye color (blue, brown, green)
#
# we can use-
# 1. Tetrachoric Correlation: Used to calculate the correlation between binary categorical variables.
#
# Binary variables are variables that can only take on one of two possible values.
# The value for tetrachoric correlation ranges from -1 to 1 where -1 indicates a strong negative correlation, 0 indicates no correlation, and 1 indicates a strong positive correlation.
#
# 2. Polychoric Correlation: Used to calculate the correlation between ordinal categorical variables.
#
# Ordinal variables are variables whose possible values have a natural order.
# The value for polychoric correlation ranges from -1 to 1 where -1 indicates a strong negative correlation, 0 indicates no correlation, and 1 indicates a strong positive correlation.
#
# 3. Cramer’s V: Used to calculate the correlation between nominal categorical variables.
#
# Nominal variables are ones that take on category labels but have no natural ordering.
# The value for Cramer’s V ranges from 0 to 1, with 0 indicating no association between the variables and 1 indicating a strong association between the variables.
