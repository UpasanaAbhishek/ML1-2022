# %% [markdown]
# # **ASSIGNMENT 2**

# %% [markdown]
# ## **21BDA50**

# %% [markdown]
# ## **ANAGHA ASHOK**

# %% [markdown]
# 2.Fit one SLR and one MLR model using sklearn. Check if the assumptions of LR have been met.

# %%
import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
sns.set(style = "darkgrid")
sns.set(rc = {'figure.figsize':(11.7,8.27)})

# %%
df = pd.read_csv("Fish.csv")

# %%
df.head()
# Out:
#   Species  Weight  Length1  Length2  Length3   Height   Width
# 0   Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1   Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2   Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3   Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4   Bream   430.0     26.5     29.0     34.0  12.4440  5.1340

# %%
sns.regplot(x="Height", y="Weight", data = df)
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %% [markdown]
# **SIMPLE LINEAR REGRESSION**

# %%
model_df = df[['Species','Height', 'Weight']]

# %%
model_df
# Out:
#     Species   Height  Weight
# 0     Bream  11.5200   242.0
# 1     Bream  12.4800   290.0
# 2     Bream  12.3778   340.0
# 3     Bream  12.7300   363.0
# 4     Bream  12.4440   430.0
# ..      ...      ...     ...
# 154   Smelt   2.0904    12.2
# 155   Smelt   2.4300    13.4
# 156   Smelt   2.2770    12.2
# 157   Smelt   2.8728    19.7
# 158   Smelt   2.9322    19.9
#
# [159 rows x 3 columns]

# %%
x = model_df.Height

# %%
y = model_df.Weight

# %%
model = LinearRegression()

# %%
model.fit(np.array(x).reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# -144.3859711547874

# %%
model.coef_
# Out:
# array([60.49635121])

# %%
model.score(np.array(x).reshape(-1,1),y)
# Out:
# 0.5246761559328882

# %% [markdown]
# **MULTIPLE LINEAR REGRESSION**

# %%
df = pd.read_csv('Fish.csv')

# %%
df
# Out:
#     Species  Weight  Length1  Length2  Length3   Height   Width
# 0     Bream   242.0     23.2     25.4     30.0  11.5200  4.0200
# 1     Bream   290.0     24.0     26.3     31.2  12.4800  4.3056
# 2     Bream   340.0     23.9     26.5     31.1  12.3778  4.6961
# 3     Bream   363.0     26.3     29.0     33.5  12.7300  4.4555
# 4     Bream   430.0     26.5     29.0     34.0  12.4440  5.1340
# ..      ...     ...      ...      ...      ...      ...     ...
# 154   Smelt    12.2     11.5     12.2     13.4   2.0904  1.3936
# 155   Smelt    13.4     11.7     12.4     13.5   2.4300  1.2690
# 156   Smelt    12.2     12.1     13.0     13.8   2.2770  1.2558
# 157   Smelt    19.7     13.2     14.3     15.2   2.8728  2.0672
# 158   Smelt    19.9     13.8     15.0     16.2   2.9322  1.8792
#
# [159 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['Species', 'Weight', 'Length1', 'Length2', 'Length3', 'Height',
#        'Width'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Weight     Length1     Length2     Length3      Height       Width
# count   159.000000  159.000000  159.000000  159.000000  159.000000  159.000000
# mean    398.326415   26.247170   28.415723   31.227044    8.970994    4.417486
# std     357.978317    9.996441   10.716328   11.610246    4.286208    1.685804
# min       0.000000    7.500000    8.400000    8.800000    1.728400    1.047600
# 25%     120.000000   19.050000   21.000000   23.150000    5.944800    3.385650
# 50%     273.000000   25.200000   27.300000   29.400000    7.786000    4.248500
# 75%     650.000000   32.700000   35.500000   39.650000   12.365900    5.584500
# max    1650.000000   59.000000   63.400000   68.000000   18.957000    8.142000

# %%
df.isna().sum()
# Out:
# Species    0
# Weight     0
# Length1    0
# Length2    0
# Length3    0
# Height     0
# Width      0
# dtype: int64

# %%
df.corr()
# Out:
#            Weight   Length1   Length2   Length3    Height     Width
# Weight   1.000000  0.915712  0.918618  0.923044  0.724345  0.886507
# Length1  0.915712  1.000000  0.999517  0.992031  0.625378  0.867050
# Length2  0.918618  0.999517  1.000000  0.994103  0.640441  0.873547
# Length3  0.923044  0.992031  0.994103  1.000000  0.703409  0.878520
# Height   0.724345  0.625378  0.640441  0.703409  1.000000  0.792881
# Width    0.886507  0.867050  0.873547  0.878520  0.792881  1.000000

# %%
X = df[['Weight', 'Length1', 'Length2','Length3','Height']]
y = df['Width']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=4)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 0.45554363539667264

# %%
model.coef_
# Out:
# array([ 2.55495695e-04,  1.55055608e-01,  4.78195161e-01, -5.36734339e-01,
#         3.32217346e-01])

# %%
model.score(X_train, y_train)
# Out:
# 0.9185102909233936

# %%
model.predict(X_test)
# Out:
# array([5.47131476, 4.92542072, 5.98237025, 7.25216783, 3.04212332,
#        7.14853548, 5.19247222, 5.89776048, 3.19169274, 3.26453707,
#        1.4580794 , 6.25643431, 4.41257611, 7.03158455, 5.97513024,
#        3.64097731, 5.79101831, 5.62276536, 3.30279499, 4.82267495,
#        6.4736008 , 5.48470609, 5.20208273, 3.32646719, 1.36651385,
#        3.01105716, 5.13451923, 3.23531994, 4.3400949 , 7.0930649 ,
#        4.95733607, 3.03017952])

# %%
y_test.values
# Out:
# array([5.1708, 4.5765, 6.09  , 7.4165, 3.3957, 7.2772, 4.368 , 5.1338,
#        3.8203, 3.325 , 1.16  , 6.1984, 4.144 , 6.603 , 5.589 , 2.9181,
#        6.0532, 5.376 , 2.673 , 4.9274, 7.4934, 5.7276, 4.8146, 3.995 ,
#        1.0476, 2.3265, 5.2785, 3.8   , 4.6961, 6.3705, 4.459 , 3.3216])

# %%
model.score(X_test, model.predict(X_test))
# Out:
# 1.0

# %%
model.score(X_test, model.predict(X_test))
# Out:
# 1.0

# %%
model.score(X_test, y_test)
# Out:
# 0.9144850883180387

# %%
model.score(X_train, y_train)
# Out:
# 0.9185102909233936

# %% [markdown]
# **ASSUMPTIONS OF LR**

# %%
sns.pairplot(df,x_vars=["Weight","Length1",'Length2','Length3', 'Height',], y_vars='Width')
