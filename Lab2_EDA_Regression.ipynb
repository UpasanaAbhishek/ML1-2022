# %% [markdown]
# Name : Sneha T
#
# Register Number: 21BDA30
#
# ML - 1 - Assignment2

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(style="darkgrid")

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})

# %%
car_details = df = pd.read_csv('Cars.csv')

# %%
#Know the data
car_details.head(5)
# Out:
#                        name  year  selling_price  km_driven    fuel  \
# 0             Maruti 800 AC  2007          60000      70000  Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000      50000  Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000     100000  Diesel
# 3    Datsun RediGO T Option  2017         250000      46000  Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000     141000  Diesel
#
#   seller_type transmission         owner
# 0  Individual       Manual   First Owner
# 1  Individual       Manual   First Owner
# 2  Individual       Manual   First Owner
# 3  Individual       Manual   First Owner
# 4  Individual       Manual  Second Owner

# %%
car_details.tail(5)
# Out:
#                                      name  year  selling_price  km_driven  \
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# 4335  Diesel  Individual       Manual  Second Owner
# 4336  Diesel  Individual       Manual  Second Owner
# 4337  Petrol  Individual       Manual  Second Owner
# 4338  Diesel  Individual       Manual   First Owner
# 4339  Petrol  Individual       Manual   First Owner

# %%
car_details.sample(5)
# Out:
#                                      name  year  selling_price  km_driven  \
# 3629             Maruti Wagon R VXI BS IV  2015         320000      40000
# 3909               Hyundai EON Magna Plus  2018         360000       6000
# 538   Hyundai Verna VTVT 1.6 AT SX Option  2017        1100000      10000
# 324                Mahindra XUV500 W8 2WD  2012         850000     212814
# 1484                     Mahindra Xylo D4  2010         320000      90000
#
#         fuel seller_type transmission        owner
# 3629  Petrol  Individual       Manual  First Owner
# 3909  Petrol  Individual       Manual  First Owner
# 538   Petrol  Individual    Automatic  First Owner
# 324   Diesel      Dealer       Manual  First Owner
# 1484  Diesel  Individual       Manual  Third Owner

# %%
car_details.shape
# Out:
# (4340, 8)

# %%
car_details['name'].value_counts()
# Out:
# Maruti Swift Dzire VDI                       69
# Maruti Alto 800 LXI                          59
# Maruti Alto LXi                              47
# Maruti Alto LX                               35
# Hyundai EON Era Plus                         35
# Maruti Wagon R VXI BS IV                     29
# Maruti Swift VDI BSIV                        29
# Maruti Swift VDI                             27
# Maruti Wagon R LXI Minor                     24
# Hyundai EON Magna Plus                       24
# Maruti 800 AC                                23
# Maruti Wagon R LXI                           23
# Hyundai i10 Magna                            22
# Maruti Ritz VDi                              22
# Mahindra XUV500 W8 2WD                       22
# Maruti Alto K10 VXI                          21
# Renault KWID RXT                             21
# Hyundai Santro Xing GLS                      21
# Hyundai Creta 1.6 CRDi SX                    19
# Renault KWID 1.0 RXT Optional                17
# ...

# %%
car_details['fuel'].value_counts()
# Out:
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: fuel, dtype: int64

# %%
car_details['seller_type'].value_counts()
# Out:
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: seller_type, dtype: int64

# %%
car_details['transmission'].value_counts()
# Out:
# Manual       3892
# Automatic     448
# Name: transmission, dtype: int64

# %%
car_details['owner'].value_counts()
# Out:
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: owner, dtype: int64

# %%
car_details.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 8 columns):
# name             4340 non-null object
# year             4340 non-null int64
# selling_price    4340 non-null int64
# km_driven        4340 non-null int64
# fuel             4340 non-null object
# seller_type      4340 non-null object
# transmission     4340 non-null object
# owner            4340 non-null object
# dtypes: int64(3), object(5)
# memory usage: 271.3+ KB

# %%
car_details.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
car_details.isna().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# dtype: int64

# %%
car_details.corr()
# Out:
#                    year  selling_price  km_driven
# year           1.000000       0.413922  -0.419688
# selling_price  0.413922       1.000000  -0.192289
# km_driven     -0.419688      -0.192289   1.000000

# %% [markdown]
# # Visualize the data

# %%
#ScatterPlot
sns.scatterplot(data=car_details,x="km_driven",y="selling_price")

# %%
#Bar Plots
sns.barplot(data=car_details,x="fuel",y="selling_price")

# %%
sns.barplot(data=car_details,x="fuel",y="km_driven")

# %%
sns.countplot(data=car_details,x="fuel")
plt.title('Number of Cars grouped by fuel type')
plt.ylabel('Number of Cars')
plt.xlabel('Fuel Types')
plt.show();

# %%
sns.barplot(data=car_details,x="owner",y="selling_price")

# %%
#Barplots(subplot) 
fig,(axis1,axis2)=plt.subplots(1,2,figsize=(20,5))
sns.countplot(x="owner",data=car_details,ax=axis1)
sns.barplot(x="owner",y="selling_price",data=car_details,ax=axis2)
#The number of respective owners and the selling price at which they are selling their graphs has a similar graph except the Test Drive Car

# %%
car_details["Age"] = 2022-car_details["year"]
car_details.drop('year',axis=1,inplace=True)
sns.lineplot(data=car_details,x="Age",y="selling_price")

# %%
#Box plot
sns.catplot(x="fuel", y="km_driven",
                hue="owner", col="transmission",
                data=car_details, kind="box",
                height=7, aspect=.8);
#Here we can see that as the ownership of the car is getting passed on, the km count is increasing.

# %%
#Point-plot
sns.pointplot(x = "fuel", y = "selling_price", data= car_details)

# %%
#Simple Linear Regression

import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
car_details = df = pd.read_csv('Cars.csv')
#sns.set(style="darkgrid")

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.regplot(x="year", y="selling_price", data = car_details)

# %%
#Multiple Linear Regression
X = car_details[['year','km_driven']]
y = car_details['selling_price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=4)
model_fit = LinearRegression()
model_fit.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model_fit.intercept_
# Out:
# -112302871.92848307

# %%
model_fit.coef_
# Out:
# array([ 5.60503799e+04, -3.87727944e-01])

# %%
model_fit.score(X_train, y_train)
# Out:
# 0.16891203236581764

# %%
#model2.predict(X_test)
#y_test.values

# %%
model_fit.score(X_test, y_test)
# Out:
# 0.18411862555122105

# %%
model_fit.score(X_train, y_train)
# Out:
# 0.16891203236581764
